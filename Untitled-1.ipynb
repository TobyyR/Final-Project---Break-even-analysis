# %%
#pip install prophet

# %%
import pandas as pd
import requests
import seaborn as sns
import matplotlib.pyplot as plt
from prophet import Prophet
from prophet.plot import plot_plotly, plot_components_plotly
import numpy as np
from statsmodels.tsa.api import VAR
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
"""api_key = 'fwdNK9dZRNgFikLYyFaMEkUfd7aXwB5oIquZh405'
base_url = "https://api.eia.gov/v2/electricity/retail-sales/data/"
params = {
    "frequency": "monthly",
    "data": [
        "price"
    ],
    "facets": {
        "stateid": [
            "US"
        ]
    },
    "sort": [
        {
            "column": "period",
            "direction": "desc"
        }
    ],
    "offset": 0,
    "length": 5000
}

all_data = []
while True:
    response = requests.get(base_url, params=params)
    data = response.json()
    all_data.extend(data['response']['data'])
    if len(data['response']['data']) < params['length']:
        break
    params['offset'] += params['length']
df_elect = pd.DataFrame(all_data)

csv_file_path = 'electro_us.csv'
df_elect.to_csv(csv_file_path, index=False)
print(f"Data saved to {csv_file_path}")"""
# Out:
# 'api_key = \'fwdNK9dZRNgFikLYyFaMEkUfd7aXwB5oIquZh405\'\nbase_url = "https://api.eia.gov/v2/electricity/retail-sales/data/"\nparams = {\n    "frequency": "monthly",\n    "data": [\n        "price"\n    ],\n    "facets": {\n        "stateid": [\n            "US"\n        ]\n    },\n    "sort": [\n        {\n            "column": "period",\n            "direction": "desc"\n        }\n    ],\n    "offset": 0,\n    "length": 5000\n}\n\nall_data = []\nwhile True:\n    response = requests.get(base_url, params=params)\n    data = response.json()\n    all_data.extend(data[\'response\'][\'data\'])\n    if len(data[\'response\'][\'data\']) < params[\'length\']:\n        break\n    params[\'offset\'] += params[\'length\']\ndf_elect = pd.DataFrame(all_data)\n\ncsv_file_path = \'electro_us.csv\'\ndf_elect.to_csv(csv_file_path, index=False)\nprint(f"Data saved to {csv_file_path}")'

# %%
df3 = pd.read_csv("data_elect.csv")
df3
# Out:
#        period stateid stateDescription sectorid      sectorName  price  \
# 0     2024-04      US       U.S. Total      ALL     all sectors  12.71
# 1     2024-04      US       U.S. Total      TRA  transportation  12.64
# 2     2024-04      US       U.S. Total      RES     residential  16.88
# 3     2024-04      US       U.S. Total      OTH           other    NaN
# 4     2024-04      US       U.S. Total      IND      industrial   7.82
# ...       ...     ...              ...      ...             ...    ...
# 1675  2001-01      US       U.S. Total      COM      commercial   7.25
# 1676  2001-01      US       U.S. Total      IND      industrial   4.73
# 1677  2001-01      US       U.S. Total      OTH           other   6.48
# 1678  2001-01      US       U.S. Total      RES     residential   7.73
# 1679  2001-01      US       U.S. Total      TRA  transportation    NaN
#
#                  price-units
# 0     cents per kilowatthour
# 1     cents per kilowatthour
# 2     cents per kilowatthour
# 3     cents per kilowatthour
# 4     cents per kilowatthour
# ...                      ...
# 1675  cents per kilowatthour
# 1676  cents per kilowatthour
# 1677  cents per kilowatthour
# 1678  cents per kilowatthour
# 1679  cents per kilowatthour
#
# [1680 rows x 7 columns]

# %%
df4 = pd.read_csv("petro_2.csv")
df4
# Out:
#           period duoarea area-name product       product-name process  \
# 0     2024-07-01     NUS      U.S.    EPMM  Midgrade Gasoline     PTE
# 1     2024-07-01     NUS      U.S.   EPD2D        No 2 Diesel     PTE
# 2     2024-07-01     NUS      U.S.    EPMR   Regular Gasoline     PTE
# 3     2024-07-01     NUS      U.S.    EPMP   Premium Gasoline     PTE
# 4     2024-06-24     NUS      U.S.    EPMR   Regular Gasoline     PTE
# ...          ...     ...       ...     ...                ...     ...
# 6434  1990-09-17     NUS      U.S.    EPMR   Regular Gasoline     PTE
# 6435  1990-09-10     NUS      U.S.    EPMR   Regular Gasoline     PTE
# 6436  1990-09-03     NUS      U.S.    EPMR   Regular Gasoline     PTE
# 6437  1990-08-27     NUS      U.S.    EPMR   Regular Gasoline     PTE
# 6438  1990-08-20     NUS      U.S.    EPMR   Regular Gasoline     PTE
#
#       process-name                 series  \
# 0     Retail Sales   EMM_EPMM_PTE_NUS_DPG
# 1     Retail Sales  EMD_EPD2D_PTE_NUS_DPG
# 2     Retail Sales   EMM_EPMR_PTE_NUS_DPG
# 3     Retail Sales   EMM_EPMP_PTE_NUS_DPG
# 4     Retail Sales   EMM_EPMR_PTE_NUS_DPG
# ...            ...                    ...
# 6434  Retail Sales   EMM_EPMR_PTE_NUS_DPG
# 6435  Retail Sales   EMM_EPMR_PTE_NUS_DPG
# 6436  Retail Sales   EMM_EPMR_PTE_NUS_DPG
# 6437  Retail Sales   EMM_EPMR_PTE_NUS_DPG
# 6438  Retail Sales   EMM_EPMR_PTE_NUS_DPG
#
#                                      series-description  value  units
# 0     U.S. Midgrade All Formulations Retail Gasoline...  3.990  $/GAL
# 1     U.S. No 2 Diesel Retail Prices (Dollars per Ga...  3.813  $/GAL
# 2     U.S. Regular All Formulations Retail Gasoline ...  3.479  $/GAL
# 3     U.S. Premium All Formulations Retail Gasoline ...  4.344  $/GAL
# 4     U.S. Regular All Formulations Retail Gasoline ...  3.438  $/GAL
# ...                                                 ...    ...    ...
# 6434  U.S. Regular All Formulations Retail Gasoline ...  1.266  $/GAL
# 6435  U.S. Regular All Formulations Retail Gasoline ...  1.252  $/GAL
# 6436  U.S. Regular All Formulations Retail Gasoline ...  1.242  $/GAL
# 6437  U.S. Regular All Formulations Retail Gasoline ...  1.245  $/GAL
# 6438  U.S. Regular All Formulations Retail Gasoline ...  1.191  $/GAL
#
# [6439 rows x 11 columns]

# %%
df1 = pd.read_csv("petro.csv")
df1
# Out:
#            period duoarea   area-name product       product-name process  \
# 0      2024-06-17     SWA  WASHINGTON    EPMM  Midgrade Gasoline     PTE
# 1      2024-06-17     SOH        OHIO    EPMR   Regular Gasoline     PTE
# 2      2024-06-17     SCA  CALIFORNIA    EPMM  Midgrade Gasoline     PTE
# 3      2024-06-17     SNY    NEW YORK    EPMP   Premium Gasoline     PTE
# 4      2024-06-17     SWA  WASHINGTON    EPMR   Regular Gasoline     PTE
# ...           ...     ...         ...     ...                ...     ...
# 33538  1995-07-31     SCA  CALIFORNIA   EPD2D        No 2 Diesel     PTE
# 33539  1995-07-24     SCA  CALIFORNIA   EPD2D        No 2 Diesel     PTE
# 33540  1995-07-17     SCA  CALIFORNIA   EPD2D        No 2 Diesel     PTE
# 33541  1995-07-10     SCA  CALIFORNIA   EPD2D        No 2 Diesel     PTE
# 33542  1995-07-03     SCA  CALIFORNIA   EPD2D        No 2 Diesel     PTE
#
#        process-name                 series  \
# 0      Retail Sales   EMM_EPMM_PTE_SWA_DPG
# 1      Retail Sales   EMM_EPMR_PTE_SOH_DPG
# 2      Retail Sales   EMM_EPMM_PTE_SCA_DPG
# 3      Retail Sales   EMM_EPMP_PTE_SNY_DPG
# 4      Retail Sales   EMM_EPMR_PTE_SWA_DPG
# ...             ...                    ...
# 33538  Retail Sales  EMD_EPD2D_PTE_SCA_DPG
# 33539  Retail Sales  EMD_EPD2D_PTE_SCA_DPG
# 33540  Retail Sales  EMD_EPD2D_PTE_SCA_DPG
# 33541  Retail Sales  EMD_EPD2D_PTE_SCA_DPG
# 33542  Retail Sales  EMD_EPD2D_PTE_SCA_DPG
#
#                                       series-description  value  units
# 0      Washington Midgrade All Formulations Retail Ga...  4.538  $/GAL
# 1      Ohio Regular All Formulations Retail Gasoline ...  3.439  $/GAL
# 2      California Midgrade All Formulations Retail Ga...  4.925  $/GAL
# 3      New York Premium All Formulations Retail Gasol...  4.322  $/GAL
# 4      Washington Regular All Formulations Retail Gas...  4.180  $/GAL
# ...                                                  ...    ...    ...
# 33538  California No 2 Diesel Retail Prices (Dollars ...  1.258  $/GAL
# 33539  California No 2 Diesel Retail Prices (Dollars ...  1.258  $/GAL
# 33540  California No 2 Diesel Retail Prices (Dollars ...  1.264  $/GAL
# 33541  California No 2 Diesel Retail Prices (Dollars ...  1.274  $/GAL
# 33542  California No 2 Diesel Retail Prices (Dollars ...  1.277  $/GAL
#
# [33543 rows x 11 columns]

# %%
df2 = pd.read_csv("electro.csv")
df2
# Out:
#         period stateid stateDescription sectorid      sectorName   customers  \
# 0      2024-03      TX            Texas      ALL     all sectors  14220334.0
# 1      2024-03      MA    Massachusetts      TRA  transportation         2.0
# 2      2024-03      MA    Massachusetts      RES     residential   2941671.0
# 3      2024-03      MA    Massachusetts      OTH           other         NaN
# 4      2024-03      MA    Massachusetts      IND      industrial     10192.0
# ...        ...     ...              ...      ...             ...         ...
# 15061  2001-01      MN        Minnesota      COM      commercial         NaN
# 15062  2001-01      MN        Minnesota      IND      industrial         NaN
# 15063  2001-01      MN        Minnesota      OTH           other         NaN
# 15064  2001-01      MN        Minnesota      RES     residential         NaN
# 15065  2001-01      MN        Minnesota      TRA  transportation         NaN
#
#        price      customers-units             price-units
# 0       9.51  number of customers  cents per kilowatthour
# 1       9.40  number of customers  cents per kilowatthour
# 2      29.66  number of customers  cents per kilowatthour
# 3        NaN  number of customers  cents per kilowatthour
# 4      17.97  number of customers  cents per kilowatthour
# ...      ...                  ...                     ...
# 15061   4.98  number of customers  cents per kilowatthour
# 15062   4.32  number of customers  cents per kilowatthour
# 15063   6.79  number of customers  cents per kilowatthour
# 15064   7.03  number of customers  cents per kilowatthour
# 15065    NaN  number of customers  cents per kilowatthour
#
# [15066 rows x 9 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33543 entries, 0 to 33542
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   period              33543 non-null  object
#  1   duoarea             33543 non-null  object
#  2   area-name           33543 non-null  object
#  3   product             33543 non-null  object
#  4   product-name        33543 non-null  object
#  5   process             33543 non-null  object
#  6   process-name        33543 non-null  object
#  7   series              33543 non-null  object
#  8   series-description  33543 non-null  object
#  9   value               33543 non-null  float64
#  10  units               33543 non-null  object
# dtypes: float64(1), object(10)
# memory usage: 2.8+ MB

# %%
df1['period'] = pd.to_datetime(df1['period'])
df2['period'] = pd.to_datetime(df2['period'])
df3['period'] = pd.to_datetime(df3['period'])
df4["period"] = pd.to_datetime(df4["period"])

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15066 entries, 0 to 15065
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   period            15066 non-null  datetime64[ns]
#  1   stateid           15066 non-null  object
#  2   stateDescription  15066 non-null  object
#  3   sectorid          15066 non-null  object
#  4   sectorName        15066 non-null  object
#  5   customers         8776 non-null   float64
#  6   price             12557 non-null  float64
#  7   customers-units   15066 non-null  object
#  8   price-units       15066 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(6)
# memory usage: 1.0+ MB

# %%
df1.isna().sum()
# Out:
# period                0
# duoarea               0
# area-name             0
# product               0
# product-name          0
# process               0
# process-name          0
# series                0
# series-description    0
# value                 0
# units                 0
# dtype: int64

# %%
df2.isna().sum()
# Out:
# period                 0
# stateid                0
# stateDescription       0
# sectorid               0
# sectorName             0
# customers           6290
# price               2509
# customers-units        0
# price-units            0
# dtype: int64

# %%
def delete_columns(df):
    # List of columns to be deleted from the DataFrame
    columns_to_delete = ['stateDescription', 'sectorid', 'customers', 'customers-units']
    # Drop the specified columns from the DataFrame
    # inplace=True modifies the original DataFrame
    # errors='ignore' ensures that no error is raised if a column is not found in the DataFrame
    df.drop(columns=columns_to_delete, inplace=True, errors='ignore')
    # Return the modified DataFrame
    return df

# %%
df2 = delete_columns(df2)
df2
# Out:
#           period stateid      sectorName  price             price-units
# 0     2024-03-01      TX     all sectors   9.51  cents per kilowatthour
# 1     2024-03-01      MA  transportation   9.40  cents per kilowatthour
# 2     2024-03-01      MA     residential  29.66  cents per kilowatthour
# 3     2024-03-01      MA           other    NaN  cents per kilowatthour
# 4     2024-03-01      MA      industrial  17.97  cents per kilowatthour
# ...          ...     ...             ...    ...                     ...
# 15061 2001-01-01      MN      commercial   4.98  cents per kilowatthour
# 15062 2001-01-01      MN      industrial   4.32  cents per kilowatthour
# 15063 2001-01-01      MN           other   6.79  cents per kilowatthour
# 15064 2001-01-01      MN     residential   7.03  cents per kilowatthour
# 15065 2001-01-01      MN  transportation    NaN  cents per kilowatthour
#
# [15066 rows x 5 columns]

# %%
df3 = delete_columns(df3)
df3
# Out:
#          period stateid      sectorName  price             price-units
# 0    2024-04-01      US     all sectors  12.71  cents per kilowatthour
# 1    2024-04-01      US  transportation  12.64  cents per kilowatthour
# 2    2024-04-01      US     residential  16.88  cents per kilowatthour
# 3    2024-04-01      US           other    NaN  cents per kilowatthour
# 4    2024-04-01      US      industrial   7.82  cents per kilowatthour
# ...         ...     ...             ...    ...                     ...
# 1675 2001-01-01      US      commercial   7.25  cents per kilowatthour
# 1676 2001-01-01      US      industrial   4.73  cents per kilowatthour
# 1677 2001-01-01      US           other   6.48  cents per kilowatthour
# 1678 2001-01-01      US     residential   7.73  cents per kilowatthour
# 1679 2001-01-01      US  transportation    NaN  cents per kilowatthour
#
# [1680 rows x 5 columns]

# %%
def convert_price_to_liter(df):
    # Conversion factor from gallons to liters
    gallons_to_liters = 3.785
    
    # Convert the 'value' column from $/GAL to $/L
    df['value'] = df['value'] / gallons_to_liters
    
    return df

# %%
df1 = convert_price_to_liter(df1)
df1
# Out:
#           period duoarea   area-name product       product-name process  \
# 0     2024-06-17     SWA  WASHINGTON    EPMM  Midgrade Gasoline     PTE
# 1     2024-06-17     SOH        OHIO    EPMR   Regular Gasoline     PTE
# 2     2024-06-17     SCA  CALIFORNIA    EPMM  Midgrade Gasoline     PTE
# 3     2024-06-17     SNY    NEW YORK    EPMP   Premium Gasoline     PTE
# 4     2024-06-17     SWA  WASHINGTON    EPMR   Regular Gasoline     PTE
# ...          ...     ...         ...     ...                ...     ...
# 33538 1995-07-31     SCA  CALIFORNIA   EPD2D        No 2 Diesel     PTE
# 33539 1995-07-24     SCA  CALIFORNIA   EPD2D        No 2 Diesel     PTE
# 33540 1995-07-17     SCA  CALIFORNIA   EPD2D        No 2 Diesel     PTE
# 33541 1995-07-10     SCA  CALIFORNIA   EPD2D        No 2 Diesel     PTE
# 33542 1995-07-03     SCA  CALIFORNIA   EPD2D        No 2 Diesel     PTE
#
#        process-name                 series  \
# 0      Retail Sales   EMM_EPMM_PTE_SWA_DPG
# 1      Retail Sales   EMM_EPMR_PTE_SOH_DPG
# 2      Retail Sales   EMM_EPMM_PTE_SCA_DPG
# 3      Retail Sales   EMM_EPMP_PTE_SNY_DPG
# 4      Retail Sales   EMM_EPMR_PTE_SWA_DPG
# ...             ...                    ...
# 33538  Retail Sales  EMD_EPD2D_PTE_SCA_DPG
# 33539  Retail Sales  EMD_EPD2D_PTE_SCA_DPG
# 33540  Retail Sales  EMD_EPD2D_PTE_SCA_DPG
# 33541  Retail Sales  EMD_EPD2D_PTE_SCA_DPG
# 33542  Retail Sales  EMD_EPD2D_PTE_SCA_DPG
#
#                                       series-description     value  units
# 0      Washington Midgrade All Formulations Retail Ga...  1.198943  $/GAL
# 1      Ohio Regular All Formulations Retail Gasoline ...  0.908587  $/GAL
# 2      California Midgrade All Formulations Retail Ga...  1.301189  $/GAL
# 3      New York Premium All Formulations Retail Gasol...  1.141876  $/GAL
# 4      Washington Regular All Formulations Retail Gas...  1.104359  $/GAL
# ...                                                  ...       ...    ...
# 33538  California No 2 Diesel Retail Prices (Dollars ...  0.332365  $/GAL
# 33539  California No 2 Diesel Retail Prices (Dollars ...  0.332365  $/GAL
# 33540  California No 2 Diesel Retail Prices (Dollars ...  0.333950  $/GAL
# 33541  California No 2 Diesel Retail Prices (Dollars ...  0.336592  $/GAL
# 33542  California No 2 Diesel Retail Prices (Dollars ...  0.337384  $/GAL
#
# [33543 rows x 11 columns]

# %%
df4 = convert_price_to_liter(df4)

# %%
df1.rename(columns={'duoarea': 'stateid', "product-name": "product_name"}, inplace=True)
df1['product_name'] = df1['product_name'].str.replace(' ', '_')

# %%
df4.rename(columns={'duoarea': 'stateid', "product-name": "product_name"}, inplace=True)
df4['product_name'] = df4['product_name'].str.replace(' ', '_')

# %%
df1.rename(columns={"period": "ds", "value": "y"}, inplace=True)
df2.rename(columns={"period": "ds", "price": "y" }, inplace=True)
df3.rename(columns={"period": "ds", "price": "y" }, inplace=True)
df4.rename(columns={"period": "ds", "value": "y" }, inplace=True)

# %%
def delete_non_residential_rows(df):
    # Filter the DataFrame to keep only rows where sectorName is "residential"
    df = df[df['sectorName'] == 'residential']
    return df

# %%
df2 = delete_non_residential_rows(df2)
df2.isna().sum()
# Out:
# ds             0
# stateid        0
# sectorName     0
# y              0
# price-units    0
# dtype: int64

# %%
df3 = delete_non_residential_rows(df3)
df3.isna().sum()
# Out:
# ds             0
# stateid        0
# sectorName     0
# y              0
# price-units    0
# dtype: int64

# %%
df3 = delete_non_residential_rows(df3)
df3
# Out:
#              ds stateid   sectorName      y             price-units
# 2    2024-04-01      US  residential  16.88  cents per kilowatthour
# 8    2024-03-01      US  residential  16.68  cents per kilowatthour
# 14   2024-02-01      US  residential  16.10  cents per kilowatthour
# 20   2024-01-01      US  residential  15.45  cents per kilowatthour
# 29   2023-12-01      US  residential  15.73  cents per kilowatthour
# ...         ...     ...          ...    ...                     ...
# 1654 2001-05-01      US  residential   8.83  cents per kilowatthour
# 1658 2001-04-01      US  residential   8.46  cents per kilowatthour
# 1666 2001-03-01      US  residential   8.32  cents per kilowatthour
# 1670 2001-02-01      US  residential   8.04  cents per kilowatthour
# 1678 2001-01-01      US  residential   7.73  cents per kilowatthour
#
# [280 rows x 5 columns]

# %%
def split_and_save_by_stateid(df):
    # Dictionary to hold the resulting DataFrames
    dataframes = {}
    
    # Get unique stateid values
    unique_stateids = df['stateid'].unique()
    
    # Split the DataFrame into multiple DataFrames based on unique stateid
    for stateid in unique_stateids:
        # Filter the DataFrame for the current stateid
        state_df = df[df['stateid'] == stateid]
        # Add the filtered DataFrame to the dictionary
        dataframes[stateid] = state_df
        
        # Dynamically assign the DataFrame to a variable named after the stateid
        globals()[f"stateid_{stateid}"] = state_df
    
    return dataframes

# %%
def split_and_save_by_stateid_gas(df):
    # Dictionary to hold the resulting DataFrames
    dataframes = {}
    
    # Get unique stateid values
    unique_stateids = df['stateid'].unique()
    
    # Split the DataFrame into multiple DataFrames based on unique stateid
    for stateid in unique_stateids:
        # Filter the DataFrame for the current stateid
        state_df = df[df['stateid'] == stateid]
        
        # Get unique product_name values for the current state_df
        unique_product_names = state_df['product_name'].unique()
        
        # Split the state_df into multiple DataFrames based on unique product_name
        for product_name in unique_product_names:
            # Filter the state_df for the current product_name
            product_df = state_df[state_df['product_name'] == product_name]
            # Add the filtered DataFrame to the dictionary
            dataframes[f"{stateid}_{product_name}"] = product_df
            
            # Dynamically assign the DataFrame to a variable named after the stateid and product_name
            globals()[f"stateid_{stateid}_{product_name}"] = product_df
    
    return dataframes

# %%
split_and_save_by_stateid(df1)
# Out:
# {'SWA':               ds stateid   area-name product       product_name process  \
#  0     2024-06-17     SWA  WASHINGTON    EPMM  Midgrade_Gasoline     PTE
#  4     2024-06-17     SWA  WASHINGTON    EPMR   Regular_Gasoline     PTE
#  12    2024-06-17     SWA  WASHINGTON    EPMP   Premium_Gasoline     PTE
#  28    2024-06-10     SWA  WASHINGTON    EPMM  Midgrade_Gasoline     PTE
#  29    2024-06-10     SWA  WASHINGTON    EPMP   Premium_Gasoline     PTE
#  ...          ...     ...         ...     ...                ...     ...
#  30754 2003-06-02     SWA  WASHINGTON    EPMP   Premium_Gasoline     PTE
#  30764 2003-06-02     SWA  WASHINGTON    EPMR   Regular_Gasoline     PTE
#  30777 2003-05-26     SWA  WASHINGTON    EPMR   Regular_Gasoline     PTE
#  30790 2003-05-26     SWA  WASHINGTON    EPMM  Midgrade_Gasoline     PTE
#  30794 2003-05-26     SWA  WASHINGTON    EPMP   Premium_Gasoline     PTE
#
#         process-name                series  \
#  0      Retail Sales  EMM_EPMM_PTE_SWA_DPG
#  4      Retail Sales  EMM_EPMR_PTE_SWA_DPG
#  12     Retail Sales  EMM_EPMP_PTE_SWA_DPG
#  28     Retail Sales  EMM_EPMM_PTE_SWA_DPG
#  29     Retail Sales  EMM_EPMP_PTE_SWA_DPG
#  ...             ...                   ...
#  30754  Retail Sales  EMM_EPMP_PTE_SWA_DPG
#  30764  Retail Sales  EMM_EPMR_PTE_SWA_DPG
#  30777  Retail Sales  EMM_EPMR_PTE_SWA_DPG
#  30790  Retail Sales  EMM_EPMM_PTE_SWA_DPG
#  30794  Retail Sales  EMM_EPMP_PTE_SWA_DPG
#
#                                        series-description         y  units
#  0      Washington Midgrade All Formulations Retail Ga...  1.198943  $/GAL
#  4      Washington Regular All Formulations Retail Gas...  1.104359  $/GAL
#  12     Washington Premium All Formulations Retail Gas...  1.245178  $/GAL
#  28     Washington Midgrade All Formulations Retail Ga...  1.226948  $/GAL
#  29     Washington Premium All Formulations Retail Gas...  1.266843  $/GAL
#  ...                                                  ...       ...    ...
#  30754  Washington Premium All Formulations Retail Gas...  0.462880  $/GAL
#  30764  Washington Regular All Formulations Retail Gas...  0.406605  $/GAL
#  30777  Washington Regular All Formulations Retail Gas...  0.407662  $/GAL
#  30790  Washington Midgrade All Formulations Retail Ga...  0.438573  $/GAL
#  30794  Washington Premium All Formulations Retail Gas...  0.463672  $/GAL
#
#  [3299 rows x 11 columns],
#  'SOH':               ds stateid area-name product       product_name process  \
#  1     2024-06-17     SOH      OHIO    EPMR   Regular_Gasoline     PTE
#  19    2024-06-17     SOH      OHIO    EPMM  Midgrade_Gasoline     PTE
#  23    2024-06-17     SOH      OHIO    EPMP   Premium_Gasoline     PTE
#  42    2024-06-10     SOH      OHIO    EPMR   Regular_Gasoline     PTE
#  49    2024-06-10     SOH      OHIO    EPMM  Midgrade_Gasoline     PTE
#  ...          ...     ...       ...     ...                ...     ...
#  30753 2003-06-02     SOH      OHIO    EPMP   Premium_Gasoline     PTE
#  30769 2003-06-02     SOH      OHIO    EPMR   Regular_Gasoline     PTE
#  30789 2003-05-26     SOH      OHIO    EPMP   Premium_Gasoline     PTE
#  30791 2003-05-26     SOH      OHIO    EPMM  Midgrade_Gasoline     PTE
#  30792 2003-05-26     SOH      OHIO    EPMR   Regular_Gasoline     PTE
#
#         process-name                series  \
#  1      Retail Sales  EMM_EPMR_PTE_SOH_DPG
#  19     Retail Sales  EMM_EPMM_PTE_SOH_DPG
#  23     Retail Sales  EMM_EPMP_PTE_SOH_DPG
#  42     Retail Sales  EMM_EPMR_PTE_SOH_DPG
#  49     Retail Sales  EMM_EPMM_PTE_SOH_DPG
#  ...             ...                   ...
#  30753  Retail Sales  EMM_EPMP_PTE_SOH_DPG
#  30769  Retail Sales  EMM_EPMR_PTE_SOH_DPG
#  30789  Retail Sales  EMM_EPMP_PTE_SOH_DPG
#  30791  Retail Sales  EMM_EPMM_PTE_SOH_DPG
#  30792  Retail Sales  EMM_EPMR_PTE_SOH_DPG
#
#                                        series-description         y  units
#  1      Ohio Regular All Formulations Retail Gasoline ...  0.908587  $/GAL
#  19     Ohio Midgrade All Formulations Retail Gasoline...  1.042272  $/GAL
#  23     Ohio Premium All Formulations Retail Gasoline ...  1.179128  $/GAL
#  42     Ohio Regular All Formulations Retail Gasoline ...  0.842008  $/GAL
#  49     Ohio Midgrade All Formulations Retail Gasoline...  0.981506  $/GAL
#  ...                                                  ...       ...    ...
#  30753  Ohio Premium All Formulations Retail Gasoline ...  0.412417  $/GAL
#  30769  Ohio Regular All Formulations Retail Gasoline ...  0.360634  $/GAL
#  30789  Ohio Premium All Formulations Retail Gasoline ...  0.426420  $/GAL
#  30791  Ohio Midgrade All Formulations Retail Gasoline...  0.401585  $/GAL
#  30792  Ohio Regular All Formulations Retail Gasoline ...  0.375429  $/GAL
#
#  [3303 rows x 11 columns],
#  'SCA':               ds stateid   area-name product       product_name process  \
#  2     2024-06-17     SCA  CALIFORNIA    EPMM  Midgrade_Gasoline     PTE
#  9     2024-06-17     SCA  CALIFORNIA    EPMP   Premium_Gasoline     PTE
#  11    2024-06-17     SCA  CALIFORNIA   EPD2D        No_2_Diesel     PTE
#  22    2024-06-17     SCA  CALIFORNIA    EPMR   Regular_Gasoline     PTE
#  34    2024-06-10     SCA  CALIFORNIA    EPMP   Premium_Gasoline     PTE
#  ...          ...     ...         ...     ...                ...     ...
#  33538 1995-07-31     SCA  CALIFORNIA   EPD2D        No_2_Diesel     PTE
#  33539 1995-07-24     SCA  CALIFORNIA   EPD2D        No_2_Diesel     PTE
#  33540 1995-07-17     SCA  CALIFORNIA   EPD2D        No_2_Diesel     PTE
#  33541 1995-07-10     SCA  CALIFORNIA   EPD2D        No_2_Diesel     PTE
#  33542 1995-07-03     SCA  CALIFORNIA   EPD2D        No_2_Diesel     PTE
#
#         process-name                 series  \
#  2      Retail Sales   EMM_EPMM_PTE_SCA_DPG
#  9      Retail Sales   EMM_EPMP_PTE_SCA_DPG
#  11     Retail Sales  EMD_EPD2D_PTE_SCA_DPG
#  22     Retail Sales   EMM_EPMR_PTE_SCA_DPG
#  34     Retail Sales   EMM_EPMP_PTE_SCA_DPG
#  ...             ...                    ...
#  33538  Retail Sales  EMD_EPD2D_PTE_SCA_DPG
#  33539  Retail Sales  EMD_EPD2D_PTE_SCA_DPG
#  33540  Retail Sales  EMD_EPD2D_PTE_SCA_DPG
#  33541  Retail Sales  EMD_EPD2D_PTE_SCA_DPG
#  33542  Retail Sales  EMD_EPD2D_PTE_SCA_DPG
#
#                                        series-description         y  units
#  2      California Midgrade All Formulations Retail Ga...  1.301189  $/GAL
#  9      California Premium All Formulations Retail Gas...  1.332893  $/GAL
#  11     California No 2 Diesel Retail Prices (Dollars ...  1.298547  $/GAL
#  22     California Regular All Formulations Retail Gas...  1.215059  $/GAL
#  34     California Premium All Formulations Retail Gas...  1.353765  $/GAL
#  ...                                                  ...       ...    ...
#  33538  California No 2 Diesel Retail Prices (Dollars ...  0.332365  $/GAL
#  33539  California No 2 Diesel Retail Prices (Dollars ...  0.332365  $/GAL
#  33540  California No 2 Diesel Retail Prices (Dollars ...  0.333950  $/GAL
#  33541  California No 2 Diesel Retail Prices (Dollars ...  0.336592  $/GAL
#  33542  California No 2 Diesel Retail Prices (Dollars ...  0.337384  $/GAL
#
#  [5285 rows x 11 columns],
#  'SNY':               ds stateid area-name product       product_name process  \
#  3     2024-06-17     SNY  NEW YORK    EPMP   Premium_Gasoline     PTE
#  5     2024-06-17     SNY  NEW YORK    EPMM  Midgrade_Gasoline     PTE
#  18    2024-06-17     SNY  NEW YORK    EPMR   Regular_Gasoline     PTE
#  31    2024-06-10     SNY  NEW YORK    EPMP   Premium_Gasoline     PTE
#  40    2024-06-10     SNY  NEW YORK    EPMM  Midgrade_Gasoline     PTE
#  ...          ...     ...       ...     ...                ...     ...
#  33260 2000-06-12     SNY  NEW YORK    EPMP   Premium_Gasoline     PTE
#  33261 2000-06-12     SNY  NEW YORK    EPMR   Regular_Gasoline     PTE
#  33268 2000-06-05     SNY  NEW YORK    EPMM  Midgrade_Gasoline     PTE
#  33276 2000-06-05     SNY  NEW YORK    EPMR   Regular_Gasoline     PTE
#  33278 2000-06-05     SNY  NEW YORK    EPMP   Premium_Gasoline     PTE
#
#         process-name                series  \
#  3      Retail Sales  EMM_EPMP_PTE_SNY_DPG
#  5      Retail Sales  EMM_EPMM_PTE_SNY_DPG
#  18     Retail Sales  EMM_EPMR_PTE_SNY_DPG
#  31     Retail Sales  EMM_EPMP_PTE_SNY_DPG
#  40     Retail Sales  EMM_EPMM_PTE_SNY_DPG
#  ...             ...                   ...
#  33260  Retail Sales  EMM_EPMP_PTE_SNY_DPG
#  33261  Retail Sales  EMM_EPMR_PTE_SNY_DPG
#  33268  Retail Sales  EMM_EPMM_PTE_SNY_DPG
#  33276  Retail Sales  EMM_EPMR_PTE_SNY_DPG
#  33278  Retail Sales  EMM_EPMP_PTE_SNY_DPG
#
#                                        series-description         y  units
#  3      New York Premium All Formulations Retail Gasol...  1.141876  $/GAL
#  5      New York Midgrade All Formulations Retail Gaso...  1.033818  $/GAL
#  18     New York Regular All Formulations Retail Gasol...  0.916513  $/GAL
#  31     New York Premium All Formulations Retail Gasol...  1.147424  $/GAL
#  40     New York Midgrade All Formulations Retail Gaso...  1.038045  $/GAL
#  ...                                                  ...       ...    ...
#  33260  New York Premium All Formulations Retail Gasol...  0.472919  $/GAL
#  33261  New York Regular All Formulations Retail Gasol...  0.435403  $/GAL
#  33268  New York Midgrade All Formulations Retail Gaso...  0.448877  $/GAL
#  33276  New York Regular All Formulations Retail Gasol...  0.424571  $/GAL
#  33278  New York Premium All Formulations Retail Gasol...  0.463672  $/GAL
#
#  [3769 rows x 11 columns],
#  'SMA':               ds stateid      area-name product       product_name process  \
#  6     2024-06-17     SMA  MASSACHUSETTS    EPMP   Premium_Gasoline     PTE
#  8     2024-06-17     SMA  MASSACHUSETTS    EPMR   Regular_Gasoline     PTE
#  13    2024-06-17     SMA  MASSACHUSETTS    EPMM  Midgrade_Gasoline     PTE
#  33    2024-06-10     SMA  MASSACHUSETTS    EPMP   Premium_Gasoline     PTE
#  38    2024-06-10     SMA  MASSACHUSETTS    EPMR   Regular_Gasoline     PTE
#  ...          ...     ...            ...     ...                ...     ...
#  30749 2003-06-02     SMA  MASSACHUSETTS    EPMR   Regular_Gasoline     PTE
#  30766 2003-06-02     SMA  MASSACHUSETTS    EPMP   Premium_Gasoline     PTE
#  30773 2003-05-26     SMA  MASSACHUSETTS    EPMP   Premium_Gasoline     PTE
#  30784 2003-05-26     SMA  MASSACHUSETTS    EPMR   Regular_Gasoline     PTE
#  30787 2003-05-26     SMA  MASSACHUSETTS    EPMM  Midgrade_Gasoline     PTE
#
#         process-name                series  \
#  6      Retail Sales  EMM_EPMP_PTE_SMA_DPG
#  8      Retail Sales  EMM_EPMR_PTE_SMA_DPG
#  13     Retail Sales  EMM_EPMM_PTE_SMA_DPG
#  33     Retail Sales  EMM_EPMP_PTE_SMA_DPG
#  38     Retail Sales  EMM_EPMR_PTE_SMA_DPG
#  ...             ...                   ...
#  30749  Retail Sales  EMM_EPMR_PTE_SMA_DPG
#  30766  Retail Sales  EMM_EPMP_PTE_SMA_DPG
#  30773  Retail Sales  EMM_EPMP_PTE_SMA_DPG
#  30784  Retail Sales  EMM_EPMR_PTE_SMA_DPG
#  30787  Retail Sales  EMM_EPMM_PTE_SMA_DPG
#
#                                        series-description         y  units
#  6      Massachusetts Premium All Formulations Retail ...  1.154822  $/GAL
#  8      Massachusetts Regular All Formulations Retail ...  0.908058  $/GAL
#  13     Massachusetts Midgrade All Formulations Retail...  1.067635  $/GAL
#  33     Massachusetts Premium All Formulations Retail ...  1.157199  $/GAL
#  38     Massachusetts Regular All Formulations Retail ...  0.911229  $/GAL
#  ...                                                  ...       ...    ...
#  30749  Massachusetts Regular All Formulations Retail ...  0.393659  $/GAL
#  30766  Massachusetts Premium All Formulations Retail ...  0.445707  $/GAL
#  30773  Massachusetts Premium All Formulations Retail ...  0.447820  $/GAL
#  30784  Massachusetts Regular All Formulations Retail ...  0.395773  $/GAL
#  30787  Massachusetts Midgrade All Formulations Retail...  0.423514  $/GAL
#
#  [3301 rows x 11 columns],
#  'SCO':               ds stateid area-name product       product_name process  \
#  7     2024-06-17     SCO  COLORADO    EPMM  Midgrade_Gasoline     PTE
#  14    2024-06-17     SCO  COLORADO    EPMR   Regular_Gasoline     PTE
#  15    2024-06-17     SCO  COLORADO    EPMP   Premium_Gasoline     PTE
#  41    2024-06-10     SCO  COLORADO    EPMM  Midgrade_Gasoline     PTE
#  43    2024-06-10     SCO  COLORADO    EPMP   Premium_Gasoline     PTE
#  ...          ...     ...       ...     ...                ...     ...
#  33259 2000-06-12     SCO  COLORADO    EPMP   Premium_Gasoline     PTE
#  33262 2000-06-12     SCO  COLORADO    EPMM  Midgrade_Gasoline     PTE
#  33264 2000-06-05     SCO  COLORADO    EPMR   Regular_Gasoline     PTE
#  33270 2000-06-05     SCO  COLORADO    EPMM  Midgrade_Gasoline     PTE
#  33271 2000-06-05     SCO  COLORADO    EPMP   Premium_Gasoline     PTE
#
#         process-name                series  \
#  7      Retail Sales  EMM_EPMM_PTE_SCO_DPG
#  14     Retail Sales  EMM_EPMR_PTE_SCO_DPG
#  15     Retail Sales  EMM_EPMP_PTE_SCO_DPG
#  41     Retail Sales  EMM_EPMM_PTE_SCO_DPG
#  43     Retail Sales  EMM_EPMP_PTE_SCO_DPG
#  ...             ...                   ...
#  33259  Retail Sales  EMM_EPMP_PTE_SCO_DPG
#  33262  Retail Sales  EMM_EPMM_PTE_SCO_DPG
#  33264  Retail Sales  EMM_EPMR_PTE_SCO_DPG
#  33270  Retail Sales  EMM_EPMM_PTE_SCO_DPG
#  33271  Retail Sales  EMM_EPMP_PTE_SCO_DPG
#
#                                        series-description         y  units
#  7      Colorado Midgrade All Formulations Retail Gaso...  0.970410  $/GAL
#  14     Colorado Regular All Formulations Retail Gasol...  0.862351  $/GAL
#  15     Colorado Premium All Formulations Retail Gasol...  1.050462  $/GAL
#  41     Colorado Midgrade All Formulations Retail Gaso...  0.928930  $/GAL
#  43     Colorado Premium All Formulations Retail Gasol...  1.017437  $/GAL
#  ...                                                  ...       ...    ...
#  33259  Colorado Premium All Formulations Retail Gasol...  0.470806  $/GAL
#  33262  Colorado Midgrade All Formulations Retail Gaso...  0.445971  $/GAL
#  33264  Colorado Regular All Formulations Retail Gasol...  0.400793  $/GAL
#  33270  Colorado Midgrade All Formulations Retail Gaso...  0.434082  $/GAL
#  33271  Colorado Premium All Formulations Retail Gasol...  0.458388  $/GAL
#
#  [3759 rows x 11 columns],
#  'SMN':               ds stateid  area-name product       product_name process  \
#  10    2024-06-17     SMN  MINNESOTA    EPMP   Premium_Gasoline     PTE
#  17    2024-06-17     SMN  MINNESOTA    EPMR   Regular_Gasoline     PTE
#  21    2024-06-17     SMN  MINNESOTA    EPMM  Midgrade_Gasoline     PTE
#  37    2024-06-10     SMN  MINNESOTA    EPMR   Regular_Gasoline     PTE
#  45    2024-06-10     SMN  MINNESOTA    EPMM  Midgrade_Gasoline     PTE
#  ...          ...     ...        ...     ...                ...     ...
#  33256 2000-06-12     SMN  MINNESOTA    EPMP   Premium_Gasoline     PTE
#  33263 2000-06-12     SMN  MINNESOTA    EPMR   Regular_Gasoline     PTE
#  33266 2000-06-05     SMN  MINNESOTA    EPMM  Midgrade_Gasoline     PTE
#  33277 2000-06-05     SMN  MINNESOTA    EPMR   Regular_Gasoline     PTE
#  33279 2000-06-05     SMN  MINNESOTA    EPMP   Premium_Gasoline     PTE
#
#         process-name                series  \
#  10     Retail Sales  EMM_EPMP_PTE_SMN_DPG
#  17     Retail Sales  EMM_EPMR_PTE_SMN_DPG
#  21     Retail Sales  EMM_EPMM_PTE_SMN_DPG
#  37     Retail Sales  EMM_EPMR_PTE_SMN_DPG
#  45     Retail Sales  EMM_EPMM_PTE_SMN_DPG
#  ...             ...                   ...
#  33256  Retail Sales  EMM_EPMP_PTE_SMN_DPG
#  33263  Retail Sales  EMM_EPMR_PTE_SMN_DPG
#  33266  Retail Sales  EMM_EPMM_PTE_SMN_DPG
#  33277  Retail Sales  EMM_EPMR_PTE_SMN_DPG
#  33279  Retail Sales  EMM_EPMP_PTE_SMN_DPG
#
#                                        series-description         y  units
#  10     Minnesota Premium All Formulations Retail Gaso...  1.024835  $/GAL
#  17     Minnesota Regular All Formulations Retail Gaso...  0.849141  $/GAL
#  21     Minnesota Midgrade All Formulations Retail Gas...  0.937384  $/GAL
#  37     Minnesota Regular All Formulations Retail Gaso...  0.849934  $/GAL
#  45     Minnesota Midgrade All Formulations Retail Gas...  0.940026  $/GAL
#  ...                                                  ...       ...    ...
#  33256  Minnesota Premium All Formulations Retail Gaso...  0.502774  $/GAL
#  33263  Minnesota Regular All Formulations Retail Gaso...  0.468164  $/GAL
#  33266  Minnesota Midgrade All Formulations Retail Gas...  0.431440  $/GAL
#  33277  Minnesota Regular All Formulations Retail Gaso...  0.417966  $/GAL
#  33279  Minnesota Premium All Formulations Retail Gaso...  0.452576  $/GAL
#
#  [3769 rows x 11 columns],
#  'SFL':               ds stateid area-name product       product_name process  \
#  16    2024-06-17     SFL   FLORIDA    EPMM  Midgrade_Gasoline     PTE
#  20    2024-06-17     SFL   FLORIDA    EPMR   Regular_Gasoline     PTE
#  27    2024-06-17     SFL   FLORIDA    EPMP   Premium_Gasoline     PTE
#  32    2024-06-10     SFL   FLORIDA    EPMP   Premium_Gasoline     PTE
#  35    2024-06-10     SFL   FLORIDA    EPMM  Midgrade_Gasoline     PTE
#  ...          ...     ...       ...     ...                ...     ...
#  30756 2003-06-02     SFL   FLORIDA    EPMP   Premium_Gasoline     PTE
#  30759 2003-06-02     SFL   FLORIDA    EPMR   Regular_Gasoline     PTE
#  30781 2003-05-26     SFL   FLORIDA    EPMM  Midgrade_Gasoline     PTE
#  30793 2003-05-26     SFL   FLORIDA    EPMP   Premium_Gasoline     PTE
#  30796 2003-05-26     SFL   FLORIDA    EPMR   Regular_Gasoline     PTE
#
#         process-name                series  \
#  16     Retail Sales  EMM_EPMM_PTE_SFL_DPG
#  20     Retail Sales  EMM_EPMR_PTE_SFL_DPG
#  27     Retail Sales  EMM_EPMP_PTE_SFL_DPG
#  32     Retail Sales  EMM_EPMP_PTE_SFL_DPG
#  35     Retail Sales  EMM_EPMM_PTE_SFL_DPG
#  ...             ...                   ...
#  30756  Retail Sales  EMM_EPMP_PTE_SFL_DPG
#  30759  Retail Sales  EMM_EPMR_PTE_SFL_DPG
#  30781  Retail Sales  EMM_EPMM_PTE_SFL_DPG
#  30793  Retail Sales  EMM_EPMP_PTE_SFL_DPG
#  30796  Retail Sales  EMM_EPMR_PTE_SFL_DPG
#
#                                        series-description         y  units
#  16     Florida Midgrade All Formulations Retail Gasol...  0.956407  $/GAL
#  20     Florida Regular All Formulations Retail Gasoli...  0.841744  $/GAL
#  27     Florida Premium All Formulations Retail Gasoli...  1.038838  $/GAL
#  32     Florida Premium All Formulations Retail Gasoli...  1.048349  $/GAL
#  35     Florida Midgrade All Formulations Retail Gasol...  0.966711  $/GAL
#  ...                                                  ...       ...    ...
#  30756  Florida Premium All Formulations Retail Gasoli...  0.432232  $/GAL
#  30759  Florida Regular All Formulations Retail Gasoli...  0.381242  $/GAL
#  30781  Florida Midgrade All Formulations Retail Gasol...  0.405548  $/GAL
#  30793  Florida Premium All Formulations Retail Gasoli...  0.432232  $/GAL
#  30796  Florida Regular All Formulations Retail Gasoli...  0.380185  $/GAL
#
#  [3296 rows x 11 columns],
#  'STX':               ds stateid area-name product       product_name process  \
#  24    2024-06-17     STX     TEXAS    EPMR   Regular_Gasoline     PTE
#  25    2024-06-17     STX     TEXAS    EPMM  Midgrade_Gasoline     PTE
#  26    2024-06-17     STX     TEXAS    EPMP   Premium_Gasoline     PTE
#  30    2024-06-10     STX     TEXAS    EPMM  Midgrade_Gasoline     PTE
#  39    2024-06-10     STX     TEXAS    EPMR   Regular_Gasoline     PTE
#  ...          ...     ...       ...     ...                ...     ...
#  33252 2000-06-12     STX     TEXAS    EPMM  Midgrade_Gasoline     PTE
#  33254 2000-06-12     STX     TEXAS    EPMR   Regular_Gasoline     PTE
#  33265 2000-06-05     STX     TEXAS    EPMM  Midgrade_Gasoline     PTE
#  33272 2000-06-05     STX     TEXAS    EPMR   Regular_Gasoline     PTE
#  33274 2000-06-05     STX     TEXAS    EPMP   Premium_Gasoline     PTE
#
#         process-name                series  \
#  24     Retail Sales  EMM_EPMR_PTE_STX_DPG
#  25     Retail Sales  EMM_EPMM_PTE_STX_DPG
#  26     Retail Sales  EMM_EPMP_PTE_STX_DPG
#  30     Retail Sales  EMM_EPMM_PTE_STX_DPG
#  39     Retail Sales  EMM_EPMR_PTE_STX_DPG
#  ...             ...                   ...
#  33252  Retail Sales  EMM_EPMM_PTE_STX_DPG
#  33254  Retail Sales  EMM_EPMR_PTE_STX_DPG
#  33265  Retail Sales  EMM_EPMM_PTE_STX_DPG
#  33272  Retail Sales  EMM_EPMR_PTE_STX_DPG
#  33274  Retail Sales  EMM_EPMP_PTE_STX_DPG
#
#                                        series-description         y  units
#  24     Texas Regular All Formulations Retail Gasoline...  0.787318  $/GAL
#  25     Texas Midgrade All Formulations Retail Gasolin...  0.915984  $/GAL
#  26     Texas Premium All Formulations Retail Gasoline...  0.999472  $/GAL
#  30     Texas Midgrade All Formulations Retail Gasolin...  0.892206  $/GAL
#  39     Texas Regular All Formulations Retail Gasoline...  0.768296  $/GAL
#  ...                                                  ...       ...    ...
#  33252  Texas Midgrade All Formulations Retail Gasolin...  0.415324  $/GAL
#  33254  Texas Regular All Formulations Retail Gasoline...  0.389960  $/GAL
#  33265  Texas Midgrade All Formulations Retail Gasolin...  0.415059  $/GAL
#  33272  Texas Regular All Formulations Retail Gasoline...  0.389432  $/GAL
#  33274  Texas Premium All Formulations Retail Gasoline...  0.440687  $/GAL
#
#  [3762 rows x 11 columns]}

# %%
split_and_save_by_stateid(df3)
# Out:
# {'US':              ds stateid   sectorName      y             price-units
#  2    2024-04-01      US  residential  16.88  cents per kilowatthour
#  8    2024-03-01      US  residential  16.68  cents per kilowatthour
#  14   2024-02-01      US  residential  16.10  cents per kilowatthour
#  20   2024-01-01      US  residential  15.45  cents per kilowatthour
#  29   2023-12-01      US  residential  15.73  cents per kilowatthour
#  ...         ...     ...          ...    ...                     ...
#  1654 2001-05-01      US  residential   8.83  cents per kilowatthour
#  1658 2001-04-01      US  residential   8.46  cents per kilowatthour
#  1666 2001-03-01      US  residential   8.32  cents per kilowatthour
#  1670 2001-02-01      US  residential   8.04  cents per kilowatthour
#  1678 2001-01-01      US  residential   7.73  cents per kilowatthour
#
#  [280 rows x 5 columns]}

# %%
columns_to_delete_df1 = ['area-name', 'product', 'process', 'process-name', 'series', 'series-description', 'units']
df1.drop(columns=columns_to_delete_df1, inplace=True, errors='ignore')
df1
# Out:
#               ds stateid       product_name         y
# 0     2024-06-17     SWA  Midgrade_Gasoline  1.198943
# 1     2024-06-17     SOH   Regular_Gasoline  0.908587
# 2     2024-06-17     SCA  Midgrade_Gasoline  1.301189
# 3     2024-06-17     SNY   Premium_Gasoline  1.141876
# 4     2024-06-17     SWA   Regular_Gasoline  1.104359
# ...          ...     ...                ...       ...
# 33538 1995-07-31     SCA        No_2_Diesel  0.332365
# 33539 1995-07-24     SCA        No_2_Diesel  0.332365
# 33540 1995-07-17     SCA        No_2_Diesel  0.333950
# 33541 1995-07-10     SCA        No_2_Diesel  0.336592
# 33542 1995-07-03     SCA        No_2_Diesel  0.337384
#
# [33543 rows x 4 columns]

# %%
columns_to_delete_df4 = ['area-name', 'product', 'process', 'process-name', 'series', 'series-description', 'units']
df4.drop(columns=columns_to_delete_df4, inplace=True, errors='ignore')
df4
# Out:
#              ds stateid       product_name         y
# 0    2024-07-01     NUS  Midgrade_Gasoline  1.054161
# 1    2024-07-01     NUS        No_2_Diesel  1.007398
# 2    2024-07-01     NUS   Regular_Gasoline  0.919155
# 3    2024-07-01     NUS   Premium_Gasoline  1.147688
# 4    2024-06-24     NUS   Regular_Gasoline  0.908322
# ...         ...     ...                ...       ...
# 6434 1990-09-17     NUS   Regular_Gasoline  0.334478
# 6435 1990-09-10     NUS   Regular_Gasoline  0.330779
# 6436 1990-09-03     NUS   Regular_Gasoline  0.328137
# 6437 1990-08-27     NUS   Regular_Gasoline  0.328930
# 6438 1990-08-20     NUS   Regular_Gasoline  0.314663
#
# [6439 rows x 4 columns]

# %%
split_and_save_by_stateid_gas(df1)
# Out:
# {'SWA_Midgrade_Gasoline':               ds stateid       product_name         y
#  0     2024-06-17     SWA  Midgrade_Gasoline  1.198943
#  28    2024-06-10     SWA  Midgrade_Gasoline  1.226948
#  63    2024-06-03     SWA  Midgrade_Gasoline  1.245707
#  89    2024-05-27     SWA  Midgrade_Gasoline  1.256011
#  112   2024-05-20     SWA  Midgrade_Gasoline  1.260502
#  ...          ...     ...                ...       ...
#  30671 2003-06-23     SWA  Midgrade_Gasoline  0.449141
#  30699 2003-06-16     SWA  Midgrade_Gasoline  0.447820
#  30730 2003-06-09     SWA  Midgrade_Gasoline  0.438045
#  30750 2003-06-02     SWA  Midgrade_Gasoline  0.436988
#  30790 2003-05-26     SWA  Midgrade_Gasoline  0.438573
#
#  [1100 rows x 4 columns],
#  'SWA_Regular_Gasoline':               ds stateid      product_name         y
#  4     2024-06-17     SWA  Regular_Gasoline  1.104359
#  46    2024-06-10     SWA  Regular_Gasoline  1.132365
#  73    2024-06-03     SWA  Regular_Gasoline  1.157199
#  88    2024-05-27     SWA  Regular_Gasoline  1.183620
#  133   2024-05-20     SWA  Regular_Gasoline  1.182299
#  ...          ...     ...               ...       ...
#  30668 2003-06-23     SWA  Regular_Gasoline  0.419022
#  30693 2003-06-16     SWA  Regular_Gasoline  0.417966
#  30721 2003-06-09     SWA  Regular_Gasoline  0.407133
#  30764 2003-06-02     SWA  Regular_Gasoline  0.406605
#  30777 2003-05-26     SWA  Regular_Gasoline  0.407662
#
#  [1097 rows x 4 columns],
#  'SWA_Premium_Gasoline':               ds stateid      product_name         y
#  12    2024-06-17     SWA  Premium_Gasoline  1.245178
#  29    2024-06-10     SWA  Premium_Gasoline  1.266843
#  64    2024-06-03     SWA  Premium_Gasoline  1.286658
#  94    2024-05-27     SWA  Premium_Gasoline  1.317569
#  135   2024-05-20     SWA  Premium_Gasoline  1.314135
#  ...          ...     ...               ...       ...
#  30683 2003-06-23     SWA  Premium_Gasoline  0.475033
#  30706 2003-06-16     SWA  Premium_Gasoline  0.473712
#  30737 2003-06-09     SWA  Premium_Gasoline  0.463937
#  30754 2003-06-02     SWA  Premium_Gasoline  0.462880
#  30794 2003-05-26     SWA  Premium_Gasoline  0.463672
#
#  [1102 rows x 4 columns],
#  'SOH_Regular_Gasoline':               ds stateid      product_name         y
#  1     2024-06-17     SOH  Regular_Gasoline  0.908587
#  42    2024-06-10     SOH  Regular_Gasoline  0.842008
#  68    2024-06-03     SOH  Regular_Gasoline  0.876882
#  106   2024-05-27     SOH  Regular_Gasoline  0.913871
#  129   2024-05-20     SOH  Regular_Gasoline  0.951123
#  ...          ...     ...               ...       ...
#  30666 2003-06-23     SOH  Regular_Gasoline  0.367503
#  30710 2003-06-16     SOH  Regular_Gasoline  0.400264
#  30732 2003-06-09     SOH  Regular_Gasoline  0.392867
#  30769 2003-06-02     SOH  Regular_Gasoline  0.360634
#  30792 2003-05-26     SOH  Regular_Gasoline  0.375429
#
#  [1101 rows x 4 columns],
#  'SOH_Midgrade_Gasoline':               ds stateid       product_name         y
#  19    2024-06-17     SOH  Midgrade_Gasoline  1.042272
#  49    2024-06-10     SOH  Midgrade_Gasoline  0.981506
#  74    2024-06-03     SOH  Midgrade_Gasoline  1.014795
#  86    2024-05-27     SOH  Midgrade_Gasoline  1.044386
#  117   2024-05-20     SOH  Midgrade_Gasoline  1.081374
#  ...          ...     ...                ...       ...
#  30663 2003-06-23     SOH  Midgrade_Gasoline  0.393131
#  30711 2003-06-16     SOH  Midgrade_Gasoline  0.426948
#  30723 2003-06-09     SOH  Midgrade_Gasoline  0.419287
#  30745 2003-06-02     SOH  Midgrade_Gasoline  0.386790
#  30791 2003-05-26     SOH  Midgrade_Gasoline  0.401585
#
#  [1101 rows x 4 columns],
#  'SOH_Premium_Gasoline':               ds stateid      product_name         y
#  23    2024-06-17     SOH  Premium_Gasoline  1.179128
#  54    2024-06-10     SOH  Premium_Gasoline  1.116777
#  65    2024-06-03     SOH  Premium_Gasoline  1.149273
#  103   2024-05-27     SOH  Premium_Gasoline  1.177543
#  132   2024-05-20     SOH  Premium_Gasoline  1.213474
#  ...          ...     ...               ...       ...
#  30665 2003-06-23     SOH  Premium_Gasoline  0.419551
#  30692 2003-06-16     SOH  Premium_Gasoline  0.452048
#  30740 2003-06-09     SOH  Premium_Gasoline  0.443593
#  30753 2003-06-02     SOH  Premium_Gasoline  0.412417
#  30789 2003-05-26     SOH  Premium_Gasoline  0.426420
#
#  [1101 rows x 4 columns],
#  'SCA_Midgrade_Gasoline':               ds stateid       product_name         y
#  2     2024-06-17     SCA  Midgrade_Gasoline  1.301189
#  36    2024-06-10     SCA  Midgrade_Gasoline  1.318890
#  59    2024-06-03     SCA  Midgrade_Gasoline  1.352708
#  110   2024-05-27     SCA  Midgrade_Gasoline  1.371731
#  115   2024-05-20     SCA  Midgrade_Gasoline  1.393923
#  ...          ...     ...                ...       ...
#  33238 2000-06-19     SCA  Midgrade_Gasoline  0.454690
#  33255 2000-06-12     SCA  Midgrade_Gasoline  0.454690
#  33275 2000-06-05     SCA  Midgrade_Gasoline  0.454425
#  33281 2000-05-29     SCA  Midgrade_Gasoline  0.458124
#  33287 2000-05-22     SCA  Midgrade_Gasoline  0.459445
#
#  [1257 rows x 4 columns],
#  'SCA_Premium_Gasoline':               ds stateid      product_name         y
#  9     2024-06-17     SCA  Premium_Gasoline  1.332893
#  34    2024-06-10     SCA  Premium_Gasoline  1.353765
#  57    2024-06-03     SCA  Premium_Gasoline  1.386790
#  90    2024-05-27     SCA  Premium_Gasoline  1.413474
#  125   2024-05-20     SCA  Premium_Gasoline  1.428798
#  ...          ...     ...               ...       ...
#  33246 2000-06-19     SCA  Premium_Gasoline  0.481902
#  33248 2000-06-12     SCA  Premium_Gasoline  0.482166
#  33273 2000-06-05     SCA  Premium_Gasoline  0.481902
#  33282 2000-05-29     SCA  Premium_Gasoline  0.484280
#  33284 2000-05-22     SCA  Premium_Gasoline  0.485073
#
#  [1259 rows x 4 columns],
#  'SCA_No_2_Diesel':               ds stateid product_name         y
#  11    2024-06-17     SCA  No_2_Diesel  1.298547
#  47    2024-06-10     SCA  No_2_Diesel  1.297490
#  79    2024-06-03     SCA  No_2_Diesel  1.312550
#  93    2024-05-27     SCA  No_2_Diesel  1.317041
#  134   2024-05-20     SCA  No_2_Diesel  1.333950
#  ...          ...     ...          ...       ...
#  33538 1995-07-31     SCA  No_2_Diesel  0.332365
#  33539 1995-07-24     SCA  No_2_Diesel  0.332365
#  33540 1995-07-17     SCA  No_2_Diesel  0.333950
#  33541 1995-07-10     SCA  No_2_Diesel  0.336592
#  33542 1995-07-03     SCA  No_2_Diesel  0.337384
#
#  [1512 rows x 4 columns],
#  'SCA_Regular_Gasoline':               ds stateid      product_name         y
#  22    2024-06-17     SCA  Regular_Gasoline  1.215059
#  48    2024-06-10     SCA  Regular_Gasoline  1.236196
#  66    2024-06-03     SCA  Regular_Gasoline  1.270277
#  108   2024-05-27     SCA  Regular_Gasoline  1.292470
#  116   2024-05-20     SCA  Regular_Gasoline  1.311757
#  ...          ...     ...               ...       ...
#  33245 2000-06-19     SCA  Regular_Gasoline  0.427477
#  33257 2000-06-12     SCA  Regular_Gasoline  0.426420
#  33269 2000-06-05     SCA  Regular_Gasoline  0.426156
#  33283 2000-05-29     SCA  Regular_Gasoline  0.429590
#  33285 2000-05-22     SCA  Regular_Gasoline  0.431704
#
#  [1257 rows x 4 columns],
#  'SNY_Premium_Gasoline':               ds stateid      product_name         y
#  3     2024-06-17     SNY  Premium_Gasoline  1.141876
#  31    2024-06-10     SNY  Premium_Gasoline  1.147424
#  83    2024-06-03     SNY  Premium_Gasoline  1.159313
#  91    2024-05-27     SNY  Premium_Gasoline  1.164597
#  127   2024-05-20     SNY  Premium_Gasoline  1.168296
#  ...          ...     ...               ...       ...
#  33215 2000-07-03     SNY  Premium_Gasoline  0.495641
#  33231 2000-06-26     SNY  Premium_Gasoline  0.489300
#  33243 2000-06-19     SNY  Premium_Gasoline  0.485073
#  33260 2000-06-12     SNY  Premium_Gasoline  0.472919
#  33278 2000-06-05     SNY  Premium_Gasoline  0.463672
#
#  [1257 rows x 4 columns],
#  'SNY_Midgrade_Gasoline':               ds stateid       product_name         y
#  5     2024-06-17     SNY  Midgrade_Gasoline  1.033818
#  40    2024-06-10     SNY  Midgrade_Gasoline  1.038045
#  61    2024-06-03     SNY  Midgrade_Gasoline  1.048349
#  105   2024-05-27     SNY  Midgrade_Gasoline  1.053897
#  128   2024-05-20     SNY  Midgrade_Gasoline  1.054954
#  ...          ...     ...                ...       ...
#  33213 2000-07-03     SNY  Midgrade_Gasoline  0.481902
#  33217 2000-06-26     SNY  Midgrade_Gasoline  0.475561
#  33233 2000-06-19     SNY  Midgrade_Gasoline  0.470806
#  33251 2000-06-12     SNY  Midgrade_Gasoline  0.459445
#  33268 2000-06-05     SNY  Midgrade_Gasoline  0.448877
#
#  [1255 rows x 4 columns],
#  'SNY_Regular_Gasoline':               ds stateid      product_name         y
#  18    2024-06-17     SNY  Regular_Gasoline  0.916513
#  55    2024-06-10     SNY  Regular_Gasoline  0.923118
#  62    2024-06-03     SNY  Regular_Gasoline  0.935271
#  92    2024-05-27     SNY  Regular_Gasoline  0.943725
#  123   2024-05-20     SNY  Regular_Gasoline  0.948481
#  ...          ...     ...               ...       ...
#  33204 2000-07-03     SNY  Regular_Gasoline  0.457067
#  33220 2000-06-26     SNY  Regular_Gasoline  0.452048
#  33240 2000-06-19     SNY  Regular_Gasoline  0.446764
#  33261 2000-06-12     SNY  Regular_Gasoline  0.435403
#  33276 2000-06-05     SNY  Regular_Gasoline  0.424571
#
#  [1257 rows x 4 columns],
#  'SMA_Premium_Gasoline':               ds stateid      product_name         y
#  6     2024-06-17     SMA  Premium_Gasoline  1.154822
#  33    2024-06-10     SMA  Premium_Gasoline  1.157199
#  70    2024-06-03     SMA  Premium_Gasoline  1.165654
#  87    2024-05-27     SMA  Premium_Gasoline  1.167768
#  124   2024-05-20     SMA  Premium_Gasoline  1.169089
#  ...          ...     ...               ...       ...
#  30684 2003-06-23     SMA  Premium_Gasoline  0.444650
#  30702 2003-06-16     SMA  Premium_Gasoline  0.446499
#  30717 2003-06-09     SMA  Premium_Gasoline  0.442008
#  30766 2003-06-02     SMA  Premium_Gasoline  0.445707
#  30773 2003-05-26     SMA  Premium_Gasoline  0.447820
#
#  [1099 rows x 4 columns],
#  'SMA_Regular_Gasoline':               ds stateid      product_name         y
#  8     2024-06-17     SMA  Regular_Gasoline  0.908058
#  38    2024-06-10     SMA  Regular_Gasoline  0.911229
#  81    2024-06-03     SMA  Regular_Gasoline  0.924703
#  104   2024-05-27     SMA  Regular_Gasoline  0.929194
#  118   2024-05-20     SMA  Regular_Gasoline  0.929194
#  ...          ...     ...               ...       ...
#  30681 2003-06-23     SMA  Regular_Gasoline  0.393131
#  30701 2003-06-16     SMA  Regular_Gasoline  0.394980
#  30743 2003-06-09     SMA  Regular_Gasoline  0.390225
#  30749 2003-06-02     SMA  Regular_Gasoline  0.393659
#  30784 2003-05-26     SMA  Regular_Gasoline  0.395773
#
#  [1103 rows x 4 columns],
#  'SMA_Midgrade_Gasoline':               ds stateid       product_name         y
#  13    2024-06-17     SMA  Midgrade_Gasoline  1.067635
#  52    2024-06-10     SMA  Midgrade_Gasoline  1.066579
#  75    2024-06-03     SMA  Midgrade_Gasoline  1.075561
#  99    2024-05-27     SMA  Midgrade_Gasoline  1.079260
#  113   2024-05-20     SMA  Midgrade_Gasoline  1.075033
#  ...          ...     ...                ...       ...
#  30660 2003-06-23     SMA  Midgrade_Gasoline  0.420343
#  30700 2003-06-16     SMA  Midgrade_Gasoline  0.421400
#  30724 2003-06-09     SMA  Midgrade_Gasoline  0.417701
#  30744 2003-06-02     SMA  Midgrade_Gasoline  0.420608
#  30787 2003-05-26     SMA  Midgrade_Gasoline  0.423514
#
#  [1099 rows x 4 columns],
#  'SCO_Midgrade_Gasoline':               ds stateid       product_name         y
#  7     2024-06-17     SCO  Midgrade_Gasoline  0.970410
#  41    2024-06-10     SCO  Midgrade_Gasoline  0.928930
#  67    2024-06-03     SCO  Midgrade_Gasoline  0.973844
#  95    2024-05-27     SCO  Midgrade_Gasoline  0.946367
#  119   2024-05-20     SCO  Midgrade_Gasoline  0.989960
#  ...          ...     ...                ...       ...
#  33211 2000-07-03     SCO  Midgrade_Gasoline  0.468956
#  33229 2000-06-26     SCO  Midgrade_Gasoline  0.472391
#  33242 2000-06-19     SCO  Midgrade_Gasoline  0.463408
#  33262 2000-06-12     SCO  Midgrade_Gasoline  0.445971
#  33270 2000-06-05     SCO  Midgrade_Gasoline  0.434082
#
#  [1252 rows x 4 columns],
#  'SCO_Regular_Gasoline':               ds stateid      product_name         y
#  14    2024-06-17     SCO  Regular_Gasoline  0.862351
#  53    2024-06-10     SCO  Regular_Gasoline  0.831176
#  71    2024-06-03     SCO  Regular_Gasoline  0.867635
#  100   2024-05-27     SCO  Regular_Gasoline  0.847556
#  120   2024-05-20     SCO  Regular_Gasoline  0.877939
#  ...          ...     ...               ...       ...
#  33214 2000-07-03     SCO  Regular_Gasoline  0.437517
#  33218 2000-06-26     SCO  Regular_Gasoline  0.440687
#  33237 2000-06-19     SCO  Regular_Gasoline  0.431440
#  33258 2000-06-12     SCO  Regular_Gasoline  0.411361
#  33264 2000-06-05     SCO  Regular_Gasoline  0.400793
#
#  [1252 rows x 4 columns],
#  'SCO_Premium_Gasoline':               ds stateid      product_name         y
#  15    2024-06-17     SCO  Premium_Gasoline  1.050462
#  43    2024-06-10     SCO  Premium_Gasoline  1.017437
#  56    2024-06-03     SCO  Premium_Gasoline  1.053104
#  101   2024-05-27     SCO  Premium_Gasoline  1.039630
#  121   2024-05-20     SCO  Premium_Gasoline  1.065258
#  ...          ...     ...               ...       ...
#  33202 2000-07-03     SCO  Premium_Gasoline  0.496962
#  33219 2000-06-26     SCO  Premium_Gasoline  0.499868
#  33247 2000-06-19     SCO  Premium_Gasoline  0.491413
#  33259 2000-06-12     SCO  Premium_Gasoline  0.470806
#  33271 2000-06-05     SCO  Premium_Gasoline  0.458388
#
#  [1255 rows x 4 columns],
#  'SMN_Premium_Gasoline':               ds stateid      product_name         y
#  10    2024-06-17     SMN  Premium_Gasoline  1.024835
#  50    2024-06-10     SMN  Premium_Gasoline  1.024042
#  78    2024-06-03     SMN  Premium_Gasoline  1.035403
#  102   2024-05-27     SMN  Premium_Gasoline  1.086129
#  130   2024-05-20     SMN  Premium_Gasoline  1.035403
#  ...          ...     ...               ...       ...
#  33210 2000-07-03     SMN  Premium_Gasoline  0.461030
#  33223 2000-06-26     SMN  Premium_Gasoline  0.495905
#  33236 2000-06-19     SMN  Premium_Gasoline  0.519947
#  33256 2000-06-12     SMN  Premium_Gasoline  0.502774
#  33279 2000-06-05     SMN  Premium_Gasoline  0.452576
#
#  [1256 rows x 4 columns],
#  'SMN_Regular_Gasoline':               ds stateid      product_name         y
#  17    2024-06-17     SMN  Regular_Gasoline  0.849141
#  37    2024-06-10     SMN  Regular_Gasoline  0.849934
#  77    2024-06-03     SMN  Regular_Gasoline  0.856275
#  107   2024-05-27     SMN  Regular_Gasoline  0.884808
#  122   2024-05-20     SMN  Regular_Gasoline  0.857860
#  ...          ...     ...               ...       ...
#  33203 2000-07-03     SMN  Regular_Gasoline  0.427213
#  33222 2000-06-26     SMN  Regular_Gasoline  0.462087
#  33239 2000-06-19     SMN  Regular_Gasoline  0.484280
#  33263 2000-06-12     SMN  Regular_Gasoline  0.468164
#  33277 2000-06-05     SMN  Regular_Gasoline  0.417966
#
#  [1257 rows x 4 columns],
#  'SMN_Midgrade_Gasoline':               ds stateid       product_name         y
#  21    2024-06-17     SMN  Midgrade_Gasoline  0.937384
#  45    2024-06-10     SMN  Midgrade_Gasoline  0.940026
#  72    2024-06-03     SMN  Midgrade_Gasoline  0.946367
#  85    2024-05-27     SMN  Midgrade_Gasoline  0.974108
#  137   2024-05-20     SMN  Midgrade_Gasoline  0.949273
#  ...          ...     ...                ...       ...
#  33201 2000-07-03     SMN  Midgrade_Gasoline  0.440159
#  33221 2000-06-26     SMN  Midgrade_Gasoline  0.475561
#  33235 2000-06-19     SMN  Midgrade_Gasoline  0.500661
#  33249 2000-06-12     SMN  Midgrade_Gasoline  0.482431
#  33266 2000-06-05     SMN  Midgrade_Gasoline  0.431440
#
#  [1256 rows x 4 columns],
#  'SFL_Midgrade_Gasoline':               ds stateid       product_name         y
#  16    2024-06-17     SFL  Midgrade_Gasoline  0.956407
#  35    2024-06-10     SFL  Midgrade_Gasoline  0.966711
#  58    2024-06-03     SFL  Midgrade_Gasoline  1.001321
#  98    2024-05-27     SFL  Midgrade_Gasoline  1.024042
#  126   2024-05-20     SFL  Midgrade_Gasoline  1.007398
#  ...          ...     ...                ...       ...
#  30687 2003-06-23     SFL  Midgrade_Gasoline  0.414531
#  30689 2003-06-16     SFL  Midgrade_Gasoline  0.417173
#  30725 2003-06-09     SFL  Midgrade_Gasoline  0.409511
#  30747 2003-06-02     SFL  Midgrade_Gasoline  0.406869
#  30781 2003-05-26     SFL  Midgrade_Gasoline  0.405548
#
#  [1098 rows x 4 columns],
#  'SFL_Regular_Gasoline':               ds stateid      product_name         y
#  20    2024-06-17     SFL  Regular_Gasoline  0.841744
#  44    2024-06-10     SFL  Regular_Gasoline  0.853104
#  76    2024-06-03     SFL  Regular_Gasoline  0.887979
#  96    2024-05-27     SFL  Regular_Gasoline  0.909115
#  114   2024-05-20     SFL  Regular_Gasoline  0.895905
#  ...          ...     ...               ...       ...
#  30672 2003-06-23     SFL  Regular_Gasoline  0.387847
#  30708 2003-06-16     SFL  Regular_Gasoline  0.390489
#  30719 2003-06-09     SFL  Regular_Gasoline  0.382827
#  30759 2003-06-02     SFL  Regular_Gasoline  0.381242
#  30796 2003-05-26     SFL  Regular_Gasoline  0.380185
#
#  [1096 rows x 4 columns],
#  'SFL_Premium_Gasoline':               ds stateid      product_name         y
#  27    2024-06-17     SFL  Premium_Gasoline  1.038838
#  32    2024-06-10     SFL  Premium_Gasoline  1.048349
#  69    2024-06-03     SFL  Premium_Gasoline  1.081374
#  109   2024-05-27     SFL  Premium_Gasoline  1.101717
#  131   2024-05-20     SFL  Premium_Gasoline  1.086129
#  ...          ...     ...               ...       ...
#  30682 2003-06-23     SFL  Premium_Gasoline  0.439366
#  30698 2003-06-16     SFL  Premium_Gasoline  0.441215
#  30741 2003-06-09     SFL  Premium_Gasoline  0.433289
#  30756 2003-06-02     SFL  Premium_Gasoline  0.432232
#  30793 2003-05-26     SFL  Premium_Gasoline  0.432232
#
#  [1102 rows x 4 columns],
#  'STX_Regular_Gasoline':               ds stateid      product_name         y
#  24    2024-06-17     STX  Regular_Gasoline  0.787318
#  39    2024-06-10     STX  Regular_Gasoline  0.768296
#  80    2024-06-03     STX  Regular_Gasoline  0.798679
#  111   2024-05-27     STX  Regular_Gasoline  0.824042
#  138   2024-05-20     STX  Regular_Gasoline  0.817437
#  ...          ...     ...               ...       ...
#  33208 2000-07-03     STX  Regular_Gasoline  0.404756
#  33227 2000-06-26     STX  Regular_Gasoline  0.403170
#  33232 2000-06-19     STX  Regular_Gasoline  0.401057
#  33254 2000-06-12     STX  Regular_Gasoline  0.389960
#  33272 2000-06-05     STX  Regular_Gasoline  0.389432
#
#  [1253 rows x 4 columns],
#  'STX_Midgrade_Gasoline':               ds stateid       product_name         y
#  25    2024-06-17     STX  Midgrade_Gasoline  0.915984
#  30    2024-06-10     STX  Midgrade_Gasoline  0.892206
#  82    2024-06-03     STX  Midgrade_Gasoline  0.922589
#  97    2024-05-27     STX  Midgrade_Gasoline  0.948745
#  136   2024-05-20     STX  Midgrade_Gasoline  0.940555
#  ...          ...     ...                ...       ...
#  33209 2000-07-03     STX  Midgrade_Gasoline  0.429062
#  33216 2000-06-26     STX  Midgrade_Gasoline  0.428798
#  33234 2000-06-19     STX  Midgrade_Gasoline  0.426948
#  33252 2000-06-12     STX  Midgrade_Gasoline  0.415324
#  33265 2000-06-05     STX  Midgrade_Gasoline  0.415059
#
#  [1254 rows x 4 columns],
#  'STX_Premium_Gasoline':               ds stateid      product_name         y
#  26    2024-06-17     STX  Premium_Gasoline  0.999472
#  51    2024-06-10     STX  Premium_Gasoline  0.980185
#  60    2024-06-03     STX  Premium_Gasoline  1.011625
#  84    2024-05-27     STX  Premium_Gasoline  1.036196
#  139   2024-05-20     STX  Premium_Gasoline  1.030647
#  ...          ...     ...               ...       ...
#  33207 2000-07-03     STX  Premium_Gasoline  0.453897
#  33228 2000-06-26     STX  Premium_Gasoline  0.453369
#  33241 2000-06-19     STX  Premium_Gasoline  0.451783
#  33250 2000-06-12     STX  Premium_Gasoline  0.439366
#  33274 2000-06-05     STX  Premium_Gasoline  0.440687
#
#  [1255 rows x 4 columns]}

# %%
split_and_save_by_stateid_gas(df4)
# Out:
# {'NUS_Midgrade_Gasoline':              ds stateid       product_name         y
#  0    2024-07-01     NUS  Midgrade_Gasoline  1.054161
#  7    2024-06-24     NUS  Midgrade_Gasoline  1.047556
#  11   2024-06-17     NUS  Midgrade_Gasoline  1.050462
#  12   2024-06-10     NUS  Midgrade_Gasoline  1.048877
#  16   2024-06-03     NUS  Midgrade_Gasoline  1.072391
#  ...         ...     ...                ...       ...
#  6160 1994-12-26     NUS  Midgrade_Gasoline  0.309379
#  6167 1994-12-19     NUS  Midgrade_Gasoline  0.311493
#  6171 1994-12-12     NUS  Midgrade_Gasoline  0.313871
#  6173 1994-12-05     NUS  Midgrade_Gasoline  0.316248
#  6176 1994-11-28     NUS  Midgrade_Gasoline  0.316248
#
#  [1545 rows x 4 columns],
#  'NUS_No_2_Diesel':              ds stateid product_name         y
#  1    2024-07-01     NUS  No_2_Diesel  1.007398
#  6    2024-06-24     NUS  No_2_Diesel  0.995773
#  9    2024-06-17     NUS  No_2_Diesel  0.986790
#  13   2024-06-10     NUS  No_2_Diesel  0.966446
#  18   2024-06-03     NUS  No_2_Diesel  0.984412
#  ...         ...     ...          ...       ...
#  6242 1994-04-18     NUS  No_2_Diesel  0.291942
#  6244 1994-04-11     NUS  No_2_Diesel  0.292734
#  6246 1994-04-04     NUS  No_2_Diesel  0.292999
#  6249 1994-03-28     NUS  No_2_Diesel  0.292470
#  6250 1994-03-21     NUS  No_2_Diesel  0.292206
#
#  [1581 rows x 4 columns],
#  'NUS_Regular_Gasoline':              ds stateid      product_name         y
#  2    2024-07-01     NUS  Regular_Gasoline  0.919155
#  4    2024-06-24     NUS  Regular_Gasoline  0.908322
#  10   2024-06-17     NUS  Regular_Gasoline  0.907530
#  15   2024-06-10     NUS  Regular_Gasoline  0.905945
#  17   2024-06-03     NUS  Regular_Gasoline  0.928930
#  ...         ...     ...               ...       ...
#  6434 1990-09-17     NUS  Regular_Gasoline  0.334478
#  6435 1990-09-10     NUS  Regular_Gasoline  0.330779
#  6436 1990-09-03     NUS  Regular_Gasoline  0.328137
#  6437 1990-08-27     NUS  Regular_Gasoline  0.328930
#  6438 1990-08-20     NUS  Regular_Gasoline  0.314663
#
#  [1768 rows x 4 columns],
#  'NUS_Premium_Gasoline':              ds stateid      product_name         y
#  3    2024-07-01     NUS  Premium_Gasoline  1.147688
#  5    2024-06-24     NUS  Premium_Gasoline  1.141083
#  8    2024-06-17     NUS  Premium_Gasoline  1.142933
#  14   2024-06-10     NUS  Premium_Gasoline  1.144254
#  19   2024-06-03     NUS  Premium_Gasoline  1.166975
#  ...         ...     ...               ...       ...
#  6161 1994-12-26     NUS  Premium_Gasoline  0.335535
#  6165 1994-12-19     NUS  Premium_Gasoline  0.337913
#  6169 1994-12-12     NUS  Premium_Gasoline  0.340291
#  6172 1994-12-05     NUS  Premium_Gasoline  0.343725
#  6178 1994-11-28     NUS  Premium_Gasoline  0.344254
#
#  [1545 rows x 4 columns]}

# %%
# Call the function to split the DataFrame by stateid
stateid_dfs = split_and_save_by_stateid(df2)

"""# Print the resulting DataFrames
for stateid, state_df in stateid_dfs.items():
    print(f"DataFrame for stateid {stateid}:")
    print(state_df)
    print()

#Assign the DataFrames to variables named after the stateid
for stateid, state_df in stateid_dfs.items():
    globals()[f'stateid_{stateid}'] = state_df
    print(f'DataFrame variable name: stateid_{stateid}')
    print(state_df)
    print()"""
# Out:
# '# Print the resulting DataFrames\nfor stateid, state_df in stateid_dfs.items():\n    print(f"DataFrame for stateid {stateid}:")\n    print(state_df)\n    print()\n\n#Assign the DataFrames to variables named after the stateid\nfor stateid, state_df in stateid_dfs.items():\n    globals()[f\'stateid_{stateid}\'] = state_df\n    print(f\'DataFrame variable name: stateid_{stateid}\')\n    print(state_df)\n    print()'

# %%
dataframes_petrol = [stateid_SNY_Regular_Gasoline, stateid_SNY_Midgrade_Gasoline, stateid_SNY_Premium_Gasoline, stateid_SCA_Midgrade_Gasoline, stateid_SCA_No_2_Diesel, stateid_SCA_Premium_Gasoline, stateid_SCA_Regular_Gasoline, stateid_SCO_Midgrade_Gasoline, stateid_SCO_Premium_Gasoline,stateid_SCO_Regular_Gasoline, stateid_SFL_Midgrade_Gasoline, stateid_SFL_Premium_Gasoline,stateid_SFL_Regular_Gasoline, stateid_SMA_Midgrade_Gasoline, stateid_SMA_Premium_Gasoline, stateid_SMA_Regular_Gasoline, stateid_SMN_Midgrade_Gasoline, stateid_SMN_Premium_Gasoline, stateid_SMN_Regular_Gasoline, stateid_SOH_Midgrade_Gasoline, stateid_SOH_Premium_Gasoline, stateid_SOH_Regular_Gasoline, stateid_STX_Midgrade_Gasoline, stateid_STX_Premium_Gasoline, stateid_STX_Regular_Gasoline, stateid_SWA_Midgrade_Gasoline, stateid_SWA_Premium_Gasoline, stateid_SWA_Regular_Gasoline]
columns_to_drop_petrol = ["stateid", "area-name", "product", "process", "process-name", "series", "series-description", "units", "product_name"]

# %%
split_and_save_by_stateid(df1)
# Out:
# {'SWA':               ds stateid       product_name         y
#  0     2024-06-17     SWA  Midgrade_Gasoline  1.198943
#  4     2024-06-17     SWA   Regular_Gasoline  1.104359
#  12    2024-06-17     SWA   Premium_Gasoline  1.245178
#  28    2024-06-10     SWA  Midgrade_Gasoline  1.226948
#  29    2024-06-10     SWA   Premium_Gasoline  1.266843
#  ...          ...     ...                ...       ...
#  30754 2003-06-02     SWA   Premium_Gasoline  0.462880
#  30764 2003-06-02     SWA   Regular_Gasoline  0.406605
#  30777 2003-05-26     SWA   Regular_Gasoline  0.407662
#  30790 2003-05-26     SWA  Midgrade_Gasoline  0.438573
#  30794 2003-05-26     SWA   Premium_Gasoline  0.463672
#
#  [3299 rows x 4 columns],
#  'SOH':               ds stateid       product_name         y
#  1     2024-06-17     SOH   Regular_Gasoline  0.908587
#  19    2024-06-17     SOH  Midgrade_Gasoline  1.042272
#  23    2024-06-17     SOH   Premium_Gasoline  1.179128
#  42    2024-06-10     SOH   Regular_Gasoline  0.842008
#  49    2024-06-10     SOH  Midgrade_Gasoline  0.981506
#  ...          ...     ...                ...       ...
#  30753 2003-06-02     SOH   Premium_Gasoline  0.412417
#  30769 2003-06-02     SOH   Regular_Gasoline  0.360634
#  30789 2003-05-26     SOH   Premium_Gasoline  0.426420
#  30791 2003-05-26     SOH  Midgrade_Gasoline  0.401585
#  30792 2003-05-26     SOH   Regular_Gasoline  0.375429
#
#  [3303 rows x 4 columns],
#  'SCA':               ds stateid       product_name         y
#  2     2024-06-17     SCA  Midgrade_Gasoline  1.301189
#  9     2024-06-17     SCA   Premium_Gasoline  1.332893
#  11    2024-06-17     SCA        No_2_Diesel  1.298547
#  22    2024-06-17     SCA   Regular_Gasoline  1.215059
#  34    2024-06-10     SCA   Premium_Gasoline  1.353765
#  ...          ...     ...                ...       ...
#  33538 1995-07-31     SCA        No_2_Diesel  0.332365
#  33539 1995-07-24     SCA        No_2_Diesel  0.332365
#  33540 1995-07-17     SCA        No_2_Diesel  0.333950
#  33541 1995-07-10     SCA        No_2_Diesel  0.336592
#  33542 1995-07-03     SCA        No_2_Diesel  0.337384
#
#  [5285 rows x 4 columns],
#  'SNY':               ds stateid       product_name         y
#  3     2024-06-17     SNY   Premium_Gasoline  1.141876
#  5     2024-06-17     SNY  Midgrade_Gasoline  1.033818
#  18    2024-06-17     SNY   Regular_Gasoline  0.916513
#  31    2024-06-10     SNY   Premium_Gasoline  1.147424
#  40    2024-06-10     SNY  Midgrade_Gasoline  1.038045
#  ...          ...     ...                ...       ...
#  33260 2000-06-12     SNY   Premium_Gasoline  0.472919
#  33261 2000-06-12     SNY   Regular_Gasoline  0.435403
#  33268 2000-06-05     SNY  Midgrade_Gasoline  0.448877
#  33276 2000-06-05     SNY   Regular_Gasoline  0.424571
#  33278 2000-06-05     SNY   Premium_Gasoline  0.463672
#
#  [3769 rows x 4 columns],
#  'SMA':               ds stateid       product_name         y
#  6     2024-06-17     SMA   Premium_Gasoline  1.154822
#  8     2024-06-17     SMA   Regular_Gasoline  0.908058
#  13    2024-06-17     SMA  Midgrade_Gasoline  1.067635
#  33    2024-06-10     SMA   Premium_Gasoline  1.157199
#  38    2024-06-10     SMA   Regular_Gasoline  0.911229
#  ...          ...     ...                ...       ...
#  30749 2003-06-02     SMA   Regular_Gasoline  0.393659
#  30766 2003-06-02     SMA   Premium_Gasoline  0.445707
#  30773 2003-05-26     SMA   Premium_Gasoline  0.447820
#  30784 2003-05-26     SMA   Regular_Gasoline  0.395773
#  30787 2003-05-26     SMA  Midgrade_Gasoline  0.423514
#
#  [3301 rows x 4 columns],
#  'SCO':               ds stateid       product_name         y
#  7     2024-06-17     SCO  Midgrade_Gasoline  0.970410
#  14    2024-06-17     SCO   Regular_Gasoline  0.862351
#  15    2024-06-17     SCO   Premium_Gasoline  1.050462
#  41    2024-06-10     SCO  Midgrade_Gasoline  0.928930
#  43    2024-06-10     SCO   Premium_Gasoline  1.017437
#  ...          ...     ...                ...       ...
#  33259 2000-06-12     SCO   Premium_Gasoline  0.470806
#  33262 2000-06-12     SCO  Midgrade_Gasoline  0.445971
#  33264 2000-06-05     SCO   Regular_Gasoline  0.400793
#  33270 2000-06-05     SCO  Midgrade_Gasoline  0.434082
#  33271 2000-06-05     SCO   Premium_Gasoline  0.458388
#
#  [3759 rows x 4 columns],
#  'SMN':               ds stateid       product_name         y
#  10    2024-06-17     SMN   Premium_Gasoline  1.024835
#  17    2024-06-17     SMN   Regular_Gasoline  0.849141
#  21    2024-06-17     SMN  Midgrade_Gasoline  0.937384
#  37    2024-06-10     SMN   Regular_Gasoline  0.849934
#  45    2024-06-10     SMN  Midgrade_Gasoline  0.940026
#  ...          ...     ...                ...       ...
#  33256 2000-06-12     SMN   Premium_Gasoline  0.502774
#  33263 2000-06-12     SMN   Regular_Gasoline  0.468164
#  33266 2000-06-05     SMN  Midgrade_Gasoline  0.431440
#  33277 2000-06-05     SMN   Regular_Gasoline  0.417966
#  33279 2000-06-05     SMN   Premium_Gasoline  0.452576
#
#  [3769 rows x 4 columns],
#  'SFL':               ds stateid       product_name         y
#  16    2024-06-17     SFL  Midgrade_Gasoline  0.956407
#  20    2024-06-17     SFL   Regular_Gasoline  0.841744
#  27    2024-06-17     SFL   Premium_Gasoline  1.038838
#  32    2024-06-10     SFL   Premium_Gasoline  1.048349
#  35    2024-06-10     SFL  Midgrade_Gasoline  0.966711
#  ...          ...     ...                ...       ...
#  30756 2003-06-02     SFL   Premium_Gasoline  0.432232
#  30759 2003-06-02     SFL   Regular_Gasoline  0.381242
#  30781 2003-05-26     SFL  Midgrade_Gasoline  0.405548
#  30793 2003-05-26     SFL   Premium_Gasoline  0.432232
#  30796 2003-05-26     SFL   Regular_Gasoline  0.380185
#
#  [3296 rows x 4 columns],
#  'STX':               ds stateid       product_name         y
#  24    2024-06-17     STX   Regular_Gasoline  0.787318
#  25    2024-06-17     STX  Midgrade_Gasoline  0.915984
#  26    2024-06-17     STX   Premium_Gasoline  0.999472
#  30    2024-06-10     STX  Midgrade_Gasoline  0.892206
#  39    2024-06-10     STX   Regular_Gasoline  0.768296
#  ...          ...     ...                ...       ...
#  33252 2000-06-12     STX  Midgrade_Gasoline  0.415324
#  33254 2000-06-12     STX   Regular_Gasoline  0.389960
#  33265 2000-06-05     STX  Midgrade_Gasoline  0.415059
#  33272 2000-06-05     STX   Regular_Gasoline  0.389432
#  33274 2000-06-05     STX   Premium_Gasoline  0.440687
#
#  [3762 rows x 4 columns]}

# %%
def drop_columns_from_dataframes(dataframes, columns_to_drop):
    # Iterate over each DataFrame in the list of dataframes
    for df in dataframes:
        # Drop columns specified in columns_to_drop from the current DataFrame (df)
        # inplace=True modifies the DataFrame in place without returning a new DataFrame
        # errors='ignore' ignores errors if any of the specified columns are not present in df
        df.drop(columns=columns_to_drop, inplace=True, errors='ignore')

# Define a list of DataFrames 
dataframes_electro = [stateid_CA, stateid_CO, stateid_FL, stateid_MA, stateid_MN, stateid_NY, stateid_OH, stateid_TX, stateid_WA]

# Define a list of columns to drop from each DataFrame
columns_to_drop_electro = ["stateid", "sectorName", "price-units"]

# Call the function drop_columns_from_dataframes 
drop_columns_from_dataframes(dataframes_electro, columns_to_drop_electro)
# Out:
# C:\Users\torei\AppData\Local\Temp\ipykernel_7496\2316832585.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=columns_to_drop, inplace=True, errors='ignore')
# C:\Users\torei\AppData\Local\Temp\ipykernel_7496\2316832585.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=columns_to_drop, inplace=True, errors='ignore')
# C:\Users\torei\AppData\Local\Temp\ipykernel_7496\2316832585.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=columns_to_drop, inplace=True, errors='ignore')
# C:\Users\torei\AppData\Local\Temp\ipykernel_7496\2316832585.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=columns_to_drop, inplace=True, errors='ignore')
# C:\Users\torei\AppData\Local\Temp\ipykernel_7496\2316832585.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=columns_to_drop, inplace=True, errors='ignore')
# C:\Users\torei\AppData\Local\Temp\ipykernel_7496\2316832585.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=columns_to_drop, inplace=True, errors='ignore')
# C:\Users\torei\AppData\Local\Temp\ipykernel_7496\2316832585.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=columns_to_drop, inplace=True, errors='ignore')
# C:\Users\torei\AppData\Local\Temp\ipykernel_7496\2316832585.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=columns_to_drop, inplace=True, errors='ignore')
# C:\Users\torei\AppData\Local\Temp\ipykernel_7496\2316832585.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=columns_to_drop, inplace=True, errors='ignore')

# %%
drop_columns_from_dataframes([stateid_US], columns_to_drop_electro)

# %%
drop_columns_from_dataframes(dataframes_petrol, columns_to_drop_petrol)
drop_columns_from_dataframes([stateid_NUS_Midgrade_Gasoline, stateid_NUS_No_2_Diesel, stateid_NUS_Premium_Gasoline, stateid_NUS_Regular_Gasoline], columns_to_drop_petrol)

# %%
"""def split_and_save_by_product_name(df):
    # Dictionary to hold the resulting DataFrames
    dataframes = {}
    
    # Get unique stateid values
    unique_product = df['product_name'].unique()
    
    # Split the DataFrame into multiple DataFrames based on unique stateid
    for product_name in unique_product:
        # Filter the DataFrame for the current stateid
        product_df = df[df['product_name'] == product_name]
        # Add the filtered DataFrame to the dictionary
        dataframes[product_name] = product_df
        
        # Dynamically assign the DataFrame to a variable named after the stateid
        globals()[f"product_{product_name}"] = product_df
    
    return dataframes"""
# Out:
# 'def split_and_save_by_product_name(df):\n    # Dictionary to hold the resulting DataFrames\n    dataframes = {}\n    \n    # Get unique stateid values\n    unique_product = df[\'product_name\'].unique()\n    \n    # Split the DataFrame into multiple DataFrames based on unique stateid\n    for product_name in unique_product:\n        # Filter the DataFrame for the current stateid\n        product_df = df[df[\'product_name\'] == product_name]\n        # Add the filtered DataFrame to the dictionary\n        dataframes[product_name] = product_df\n        \n        # Dynamically assign the DataFrame to a variable named after the stateid\n        globals()[f"product_{product_name}"] = product_df\n    \n    return dataframes'

# %%
stateid_NUS = [stateid_NUS_Midgrade_Gasoline, stateid_NUS_No_2_Diesel, stateid_NUS_Premium_Gasoline, stateid_NUS_Regular_Gasoline]

# %%
"""product_name_dfs = split_and_save_by_product_name(df1)

# Print the resulting DataFrames
for product_name, product_df in product_name_dfs.items():
    print(f"DataFrame for stateid {product_name}:")
    print(product_df)
    print()

#Assign the DataFrames to variables named after the stateid
for product_name, product_df in product_name_dfs.items():
    globals()[f'stateid_{product_df}_{product_name}'] = product_df
    print(f'DataFrame variable name: stateid_{product_name}')
    print(product_df)
    print()
# Out:
#   Cell In[42], line 1
#     """product_name_dfs = split_and_save_by_product_name(df1)
#     ^
# SyntaxError: incomplete input

# %%
m = Prophet()
m.fit(stateid_SCA_Midgrade_Gasoline)

# %%
future = m.make_future_dataframe(periods=600)
future.tail()

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()

# %%
fig1 = m.plot(forecast)

# %%
fig2 = m.plot_components(forecast)

# %%
plot_plotly(m, forecast)

# %%
plot_components_plotly(m, forecast)

# %%
## Var 
def fit_var_model_per_dataframe(dataframes, stateid_US, initial_maxlags=15, ic='aic', forecast_steps=48):
    """
    Fits a VAR model to concatenated dataframes along the 'y' column axis and calculates various error metrics.
    
    Parameters:
    dataframes (list of pd.DataFrame): List of dataframes containing the 'y' column time series data.
    stateid_US (pd.DataFrame): Reference dataframe to concatenate with each dataframe in the list.
    initial_maxlags (int): Initial maximum number of lags to consider for the VAR model.
    ic (str): Information criterion to use for lag order selection ('aic', 'bic', 'fpe', 'hqic').
    forecast_steps (int): Number of steps to forecast into the future.

    Returns:
    dict: A dictionary containing fitted models, forecasts, and error metrics for each concatenated dataframe.
    dict: A dictionary containing the forecast dataframes for each concatenated dataframe.
    """
    
    results = {}
    dfs = {}
    
    # Ensure unique index for each dataframe
    for i, df in enumerate(dataframes):
        if not df['ds'].is_unique:
            print(f"Dataframe {i+1} has duplicate index values. Dropping duplicates.")
            df = df.drop_duplicates(subset=['ds']).reset_index(drop=True)
        dataframes[i] = df
    
    # Ensure unique index for the reference dataframe
    if not stateid_US['ds'].is_unique:
        print("Reference dataframe stateid_US has duplicate index values. Dropping duplicates.")
        stateid_US = stateid_US.drop_duplicates(subset=['ds']).reset_index(drop=True)
    
    stateid_US = stateid_US.set_index('ds')
    
    for i, df in enumerate(dataframes):
        # Concatenate current dataframe with stateid_US along the 'y' column axis
        try:
            concatenated_df = pd.concat([df.set_index('ds'), stateid_US], axis=1, keys=['y1', 'y2'])
        except ValueError as e:
            print(f"ValueError encountered during concatenation with Dataframe {i+1}: {e}")
            continue
        
        # Ensure all data is numeric
        concatenated_df = concatenated_df.apply(pd.to_numeric, errors='coerce')
        
        # Drop rows with any NaN values (if necessary)
        concatenated_df = concatenated_df.dropna()
        
        # Check the number of observations and variables
        n_obs = concatenated_df.shape[0]
        n_vars = concatenated_df.shape[1]
        
        print(f"Number of observations in concatenated Dataframe {i+1}: {n_obs}")
        print(f"Number of variables in concatenated Dataframe {i+1}: {n_vars}")

        if n_vars < 2:
            print(f"Not enough variables (columns) to fit the VAR model for Dataframe {i+1}.")
            continue
        
        # Determine the initial maxlags value based on the data size
        maxlags = min(initial_maxlags, n_obs // (2 * n_vars))
        if maxlags < 1:
            print(f"Not enough data to fit the VAR model with any lags for Dataframe {i+1}.")
            continue
        
        print(f"Initial maxlags for Dataframe {i+1}: {maxlags}")
        
        while maxlags > 0:
            try:
                # Fit the VAR model
                model = VAR(concatenated_df)
                model_fitted = model.fit(maxlags=maxlags, ic=ic)
                
                # Get the optimal number of lags
                lag_order = model_fitted.k_ar
                print(f'Optimal number of lags for Dataframe {i+1}: {lag_order}')
                
                # Forecast the time series
                forecast = model_fitted.forecast(concatenated_df.values[-lag_order:], steps=forecast_steps)
                forecast_index = pd.date_range(start=concatenated_df.index[-1] + pd.DateOffset(1), periods=forecast_steps, freq=pd.infer_freq(concatenated_df.index))
                forecast_df = pd.DataFrame(forecast, index=forecast_index, columns=concatenated_df.columns)
                
                # Save the forecast dataframe in dfs dictionary
                dfs[f'dataframe_{i+1}'] = forecast_df
                
                # Calculate error metrics for available data
                mse = mean_squared_error(concatenated_df.values[lag_order:], model_fitted.fittedvalues)
                mae = mean_absolute_error(concatenated_df.values[lag_order:], model_fitted.fittedvalues)
                r2 = r2_score(concatenated_df.values[lag_order:], model_fitted.fittedvalues)
                
                # Calculate Mean Squared Absolute Error (MSAE)
                msae = np.mean(np.square(np.abs(concatenated_df.values[lag_order:] - model_fitted.fittedvalues)))
                
                errors = {
                    'MSE': mse,
                    'MAE': mae,
                    'R2': r2,
                    'MSAE': msae
                }
                
                results[f'dataframe_{i+1}'] = {
                    'model': model_fitted,
                    'forecast': forecast_df,
                    'errors': errors
                }
                
                break  # Exit the while loop once the model is successfully fitted
            except ValueError as e:
                print(f"ValueError encountered with maxlags={maxlags} for Dataframe {i+1}: {e}")
                maxlags -= 1
        
        if maxlags == 0:
            print(f"Unable to fit VAR model for Dataframe {i+1}. Consider reducing maxlags further or checking data quality.")
    
    return results, dfs

# %%
results, dfs = fit_var_model_per_dataframe(dataframes_electro, stateid_US=stateid_US)
for key, value in results.items():
    print(f"\nResults for {key}:")
    print("Errors:", value['errors'])
    print("Forecast:\n", value['forecast'])
# Out:
# Dataframe 1 has duplicate index values. Dropping duplicates.
# Dataframe 2 has duplicate index values. Dropping duplicates.
# Dataframe 4 has duplicate index values. Dropping duplicates.
# Dataframe 6 has duplicate index values. Dropping duplicates.
# Dataframe 7 has duplicate index values. Dropping duplicates.
# Dataframe 8 has duplicate index values. Dropping duplicates.
# Dataframe 9 has duplicate index values. Dropping duplicates.
# Number of observations in concatenated Dataframe 1: 279
# Number of variables in concatenated Dataframe 1: 2
# Initial maxlags for Dataframe 1: 15
# Optimal number of lags for Dataframe 1: 14
# Number of observations in concatenated Dataframe 2: 279
# Number of variables in concatenated Dataframe 2: 2
# Initial maxlags for Dataframe 2: 15
# Optimal number of lags for Dataframe 2: 15
# Number of observations in concatenated Dataframe 3: 277
# Number of variables in concatenated Dataframe 3: 2
# Initial maxlags for Dataframe 3: 15
# Optimal number of lags for Dataframe 3: 14
# Number of observations in concatenated Dataframe 4: 279
# Number of variables in concatenated Dataframe 4: 2
# Initial maxlags for Dataframe 4: 15
# Optimal number of lags for Dataframe 4: 14
# Number of observations in concatenated Dataframe 5: 276
# Number of variables in concatenated Dataframe 5: 2
# Initial maxlags for Dataframe 5: 15
# Optimal number of lags for Dataframe 5: 15
# Number of observations in concatenated Dataframe 6: 277
# Number of variables in concatenated Dataframe 6: 2
# Initial maxlags for Dataframe 6: 15
# c:\Users\torei\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\torei\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\torei\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\torei\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\torei\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# Optimal number of lags for Dataframe 6: 15
# Number of observations in concatenated Dataframe 7: 278
# Number of variables in concatenated Dataframe 7: 2
# Initial maxlags for Dataframe 7: 15
# Optimal number of lags for Dataframe 7: 14
# Number of observations in concatenated Dataframe 8: 278
# Number of variables in concatenated Dataframe 8: 2
# Initial maxlags for Dataframe 8: 15
# Optimal number of lags for Dataframe 8: 15
# Number of observations in concatenated Dataframe 9: 279
# Number of variables in concatenated Dataframe 9: 2
# Initial maxlags for Dataframe 9: 15
# Optimal number of lags for Dataframe 9: 15
#
# Results for dataframe_1:
# Errors: {'MSE': 0.37609915125948346, 'MAE': 0.3657682593469435, 'R2': 0.9796749543526899, 'MSAE': 0.37609915125948346}
# Forecast:
#                     y1         y2
#                     y          y
# 2024-04-01  31.372775  16.705204
# 2024-05-01  32.770209  16.859584
# 2024-06-01  33.948482  16.822571
# 2024-07-01  33.106476  16.776583
# 2024-08-01  33.189500  16.984351
# 2024-09-01  33.834800  17.144880
# 2024-10-01  31.887086  17.183582
# 2024-11-01  33.427162  17.168224
# 2024-12-01  34.244230  16.918537
# 2025-01-01  34.372470  16.881984
# 2025-02-01  35.253707  17.215015
# 2025-03-01  36.479690  17.674267
# 2025-04-01  35.432585  17.873716
# 2025-05-01  36.891501  18.049146
# 2025-06-01  38.180819  18.091069
# 2025-07-01  37.762975  18.108455
# 2025-08-01  38.147327  18.335645
# 2025-09-01  38.721196  18.530559
# 2025-10-01  37.430159  18.539108
# 2025-11-01  38.847487  18.587647
# 2025-12-01  39.833403  18.484657
# 2026-01-01  40.077538  18.491008
# 2026-02-01  40.795441  18.799575
# 2026-03-01  41.780000  19.173252
# 2026-04-01  41.126570  19.405982
# 2026-05-01  42.510384  19.645164
# 2026-06-01  43.804362  19.733752
# 2026-07-01  43.822100  19.819045
# 2026-08-01  44.314858  20.059389
# 2026-09-01  44.970607  20.267438
# 2026-10-01  44.172205  20.325349
# 2026-11-01  45.476820  20.407339
# 2026-12-01  46.654913  20.402126
# 2027-01-01  47.025416  20.472860
# 2027-02-01  47.776474  20.772714
# 2027-03-01  48.729790  21.134529
# 2027-04-01  48.398481  21.391115
# 2027-05-01  49.774393  21.664461
# 2027-06-01  51.113056  21.820328
# 2027-07-01  51.450066  21.961657
# 2027-08-01  52.106502  22.227638
# 2027-09-01  52.863734  22.466023
# 2027-10-01  52.505815  22.578737
# 2027-11-01  53.792945  22.713303
# 2027-12-01  55.102371  22.786681
# 2028-01-01  55.690727  22.922194
# 2028-02-01  56.556094  23.244826
# 2028-03-01  57.578463  23.618028
#
# Results for dataframe_2:
# Errors: {'MSE': 0.04357288235108261, 'MAE': 0.1604653121451629, 'R2': 0.988019616244636, 'MSAE': 0.04357288235108263}
# Forecast:
#                     y1         y2
#                     y          y
# 2024-04-01  14.719121  16.720971
# 2024-05-01  14.752348  16.644648
# 2024-06-01  15.202706  16.614024
# 2024-07-01  15.292121  16.472165
# 2024-08-01  15.289628  16.549444
# 2024-09-01  15.388534  16.682279
# 2024-10-01  15.135015  16.671774
# 2024-11-01  15.182684  16.662115
# 2024-12-01  15.041757  16.412314
# 2025-01-01  15.177300  16.316007
# 2025-02-01  15.374111  16.640483
# 2025-03-01  15.470176  17.064067
# 2025-04-01  15.509014  17.349814
# 2025-05-01  15.500245  17.333283
# 2025-06-01  15.859449  17.203894
# 2025-07-01  15.982922  17.103538
# 2025-08-01  16.001867  17.175909
# 2025-09-01  15.987015  17.267962
# 2025-10-01  15.739623  17.256836
# 2025-11-01  15.764013  17.215459
# 2025-12-01  15.735427  17.075542
# 2026-01-01  15.884610  17.062459
# 2026-02-01  16.072005  17.293169
# 2026-03-01  16.153829  17.630184
# 2026-04-01  16.230418  17.909498
# 2026-05-01  16.223624  17.936997
# 2026-06-01  16.438368  17.835242
# 2026-07-01  16.563728  17.738284
# 2026-08-01  16.608654  17.769931
# 2026-09-01  16.561843  17.849211
# 2026-10-01  16.349264  17.848489
# 2026-11-01  16.348313  17.798741
# 2026-12-01  16.362798  17.705301
# 2027-01-01  16.521496  17.732087
# 2027-02-01  16.701145  17.934966
# 2027-03-01  16.788911  18.217813
# 2027-04-01  16.886706  18.461596
# 2027-05-01  16.901616  18.512147
# 2027-06-01  17.044537  18.442055
# 2027-07-01  17.145298  18.357396
# 2027-08-01  17.181382  18.363532
# 2027-09-01  17.138793  18.426264
# 2027-10-01  16.971889  18.436190
# 2027-11-01  16.952396  18.398044
# 2027-12-01  16.983352  18.336687
# 2028-01-01  17.139718  18.381022
# 2028-02-01  17.314098  18.567597
# 2028-03-01  17.410582  18.817363
#
# Results for dataframe_3:
# Errors: {'MSE': 0.06879741968381617, 'MAE': 0.17348824591941908, 'R2': 0.9743299194917596, 'MSAE': 0.06879741968381614}
# Forecast:
#                     y1         y2
#                     y          y
# 2024-03-02  15.083861  16.813411
# 2024-03-03  15.025558  16.819086
# 2024-03-04  15.150952  16.695768
# 2024-03-05  15.203090  16.488466
# 2024-03-06  15.042240  16.428804
# 2024-03-07  15.195395  16.535810
# 2024-03-08  15.214725  16.483314
# 2024-03-09  15.079105  16.382922
# 2024-03-10  15.172266  16.268890
# 2024-03-11  15.023631  16.239230
# 2024-03-12  15.162608  16.571446
# 2024-03-13  15.070421  16.912818
# 2024-03-14  15.113862  17.117373
# 2024-03-15  15.036514  17.151493
# 2024-03-16  15.023105  17.048779
# 2024-03-17  15.105859  16.927943
# 2024-03-18  15.056587  16.850895
# 2024-03-19  15.105814  16.839754
# 2024-03-20  15.125054  16.800644
# 2024-03-21  15.060920  16.729844
# 2024-03-22  15.085121  16.699270
# 2024-03-23  15.044661  16.761779
# 2024-03-24  15.083128  16.988572
# 2024-03-25  15.093860  17.250278
# 2024-03-26  15.094938  17.431929
# 2024-03-27  15.084207  17.486604
# 2024-03-28  15.068665  17.424621
# 2024-03-29  15.109997  17.336275
# 2024-03-30  15.121363  17.262152
# 2024-03-31  15.145863  17.216699
# 2024-04-01  15.167841  17.182086
# 2024-04-02  15.152503  17.150482
# 2024-04-03  15.163143  17.165628
# 2024-04-04  15.161316  17.260773
# 2024-04-05  15.181434  17.446579
# 2024-04-06  15.206147  17.659250
# 2024-04-07  15.216043  17.817005
# 2024-04-08  15.227861  17.879181
# 2024-04-09  15.235614  17.849731
# 2024-04-10  15.263963  17.781326
# 2024-04-11  15.293567  17.713217
# 2024-04-12  15.319541  17.662574
# 2024-04-13  15.343610  17.634161
# 2024-04-14  15.352189  17.630475
# 2024-04-15  15.366014  17.674469
# 2024-04-16  15.380355  17.782773
# 2024-04-17  15.401422  17.947963
# 2024-04-18  15.428198  18.127819
#
# Results for dataframe_4:
# Errors: {'MSE': 0.25792529470115105, 'MAE': 0.3285391711339784, 'R2': 0.985562759473371, 'MSAE': 0.2579252947011511}
# Forecast:
#                     y1         y2
#                     y          y
# 2024-04-01  30.055675  16.924211
# 2024-05-01  29.172893  17.142559
# 2024-06-01  28.488788  17.056791
# 2024-07-01  28.846426  16.925894
# 2024-08-01  29.406224  16.946505
# 2024-09-01  30.013845  17.100960
# 2024-10-01  30.129787  17.049917
# 2024-11-01  30.242489  16.911185
# 2024-12-01  30.475522  16.645644
# 2025-01-01  30.772766  16.503904
# 2025-02-01  31.185010  16.866436
# 2025-03-01  31.410992  17.331388
# 2025-04-01  31.357530  17.640816
# 2025-05-01  30.843115  17.796229
# 2025-06-01  30.304813  17.755995
# 2025-07-01  30.450374  17.653377
# 2025-08-01  30.894779  17.658922
# 2025-09-01  31.373634  17.728984
# 2025-10-01  31.570828  17.687802
# 2025-11-01  31.635757  17.541775
# 2025-12-01  31.831647  17.362625
# 2026-01-01  32.150642  17.311775
# 2026-02-01  32.482260  17.570645
# 2026-03-01  32.625022  17.968184
# 2026-04-01  32.516737  18.278226
# 2026-05-01  32.114934  18.427987
# 2026-06-01  31.750496  18.418390
# 2026-07-01  31.822509  18.352705
# 2026-08-01  32.201510  18.343745
# 2026-09-01  32.616486  18.374257
# 2026-10-01  32.868285  18.333668
# 2026-11-01  32.997424  18.210352
# 2026-12-01  33.192267  18.085139
# 2027-01-01  33.484580  18.083236
# 2027-02-01  33.770104  18.300314
# 2027-03-01  33.894493  18.643424
# 2027-04-01  33.781492  18.936112
# 2027-05-01  33.469768  19.086929
# 2027-06-01  33.212465  19.101709
# 2027-07-01  33.269556  19.060141
# 2027-08-01  33.588150  19.043521
# 2027-09-01  33.963544  19.048247
# 2027-10-01  34.240502  19.007190
# 2027-11-01  34.423874  18.908982
# 2027-12-01  34.626390  18.823894
# 2028-01-01  34.889372  18.850678
# 2028-02-01  35.137496  19.046647
# 2028-03-01  35.245523  19.347900
#
# Results for dataframe_5:
# Errors: {'MSE': 0.03822609844632016, 'MAE': 0.1525147115667395, 'R2': 0.9912770481276676, 'MSAE': 0.038226098446320175}
# Forecast:
#                     y1         y2
#                     y          y
# 2024-03-02  15.489728  16.820785
# 2024-03-03  16.160383  16.914152
# 2024-03-04  16.344311  16.789833
# 2024-03-05  16.354905  16.609319
# 2024-03-06  16.214898  16.558911
# 2024-03-07  16.021099  16.711230
# 2024-03-08  15.612855  16.725585
# 2024-03-09  14.987729  16.534316
# 2024-03-10  14.749706  16.297328
# 2024-03-11  14.952282  16.245739
# 2024-03-12  15.282559  16.518191
# 2024-03-13  15.660792  16.930712
# 2024-03-14  16.251302  17.275650
# 2024-03-15  16.862460  17.412434
# 2024-03-16  17.147615  17.327616
# 2024-03-17  17.108032  17.157396
# 2024-03-18  16.923105  17.032921
# 2024-03-19  16.619158  17.049243
# 2024-03-20  16.133194  17.041187
# 2024-03-21  15.639573  16.900708
# 2024-03-22  15.510465  16.752718
# 2024-03-23  15.758681  16.762381
# 2024-03-24  16.135583  16.985210
# 2024-03-25  16.550033  17.321508
# 2024-03-26  17.063925  17.636068
# 2024-03-27  17.568039  17.813525
# 2024-03-28  17.822877  17.792691
# 2024-03-29  17.783948  17.639882
# 2024-03-30  17.557298  17.488645
# 2024-03-31  17.184727  17.416652
# 2024-04-01  16.694763  17.359651
# 2024-04-02  16.286706  17.262050
# 2024-04-03  16.223479  17.191945
# 2024-04-04  16.500672  17.251134
# 2024-04-05  16.914305  17.464809
# 2024-04-06  17.358701  17.761196
# 2024-04-07  17.834181  18.041377
# 2024-04-08  18.250272  18.214523
# 2024-04-09  18.446004  18.222197
# 2024-04-10  18.380119  18.096267
# 2024-04-11  18.121308  17.936197
# 2024-04-12  17.722158  17.814134
# 2024-04-13  17.257337  17.722168
# 2024-04-14  16.919761  17.646411
# 2024-04-15  16.905075  17.632837
# 2024-04-16  17.201012  17.737070
# 2024-04-17  17.639986  17.956658
# 2024-04-18  18.105746  18.230081
#
# Results for dataframe_6:
# Errors: {'MSE': 0.15174091965162226, 'MAE': 0.2645377864323881, 'R2': 0.9689689884258257, 'MSAE': 0.1517409196516223}
# Forecast:
#                     y1         y2
#                     y          y
# 2024-03-02  23.225669  16.879092
# 2024-03-03  23.355296  16.925751
# 2024-03-04  23.956630  16.891260
# 2024-03-05  24.319208  16.788631
# 2024-03-06  24.292247  16.910024
# 2024-03-07  24.386745  17.166727
# 2024-03-08  23.848885  17.170137
# 2024-03-09  23.537033  17.020756
# 2024-03-10  23.168931  16.682717
# 2024-03-11  23.702529  16.599675
# 2024-03-12  24.076498  16.858799
# 2024-03-13  23.744620  17.263425
# 2024-03-14  23.557289  17.576093
# 2024-03-15  23.658002  17.615298
# 2024-03-16  24.113553  17.516881
# 2024-03-17  24.370341  17.422653
# 2024-03-18  24.399255  17.463413
# 2024-03-19  24.377560  17.606670
# 2024-03-20  24.030754  17.655024
# 2024-03-21  23.618230  17.523776
# 2024-03-22  23.389129  17.259877
# 2024-03-23  23.737698  17.179290
# 2024-03-24  24.082623  17.363391
# 2024-03-25  24.030567  17.697764
# 2024-03-26  23.941284  17.983595
# 2024-03-27  24.061694  18.077475
# 2024-03-28  24.420111  18.026602
# 2024-03-29  24.639753  17.937854
# 2024-03-30  24.711046  17.943850
# 2024-03-31  24.687687  18.042150
# 2024-04-01  24.431983  18.098610
# 2024-04-02  24.073509  18.017528
# 2024-04-03  23.907203  17.841614
# 2024-04-04  24.156150  17.775476
# 2024-04-05  24.469952  17.917784
# 2024-04-06  24.544840  18.205503
# 2024-04-07  24.532576  18.475500
# 2024-04-08  24.650582  18.602679
# 2024-04-09  24.912410  18.590699
# 2024-04-10  25.098703  18.520931
# 2024-04-11  25.182374  18.506356
# 2024-04-12  25.165234  18.568954
# 2024-04-13  24.968087  18.623065
# 2024-04-14  24.673939  18.582229
# 2024-04-15  24.535653  18.470158
# 2024-04-16  24.715358  18.426036
# 2024-04-17  24.992326  18.541896
# 2024-04-18  25.127661  18.786380
#
# Results for dataframe_7:
# Errors: {'MSE': 0.04646162168129194, 'MAE': 0.16507416572042669, 'R2': 0.9883766881660252, 'MSAE': 0.04646162168129195}
# Forecast:
#                     y1         y2
#                     y          y
# 2024-03-02  16.646851  16.818034
# 2024-03-03  17.013349  16.888703
# 2024-03-04  17.093658  16.734954
# 2024-03-05  16.790237  16.585056
# 2024-03-06  16.551133  16.572812
# 2024-03-07  16.415030  16.754927
# 2024-03-08  16.528216  16.711798
# 2024-03-09  16.585657  16.564154
# 2024-03-10  16.352518  16.313734
# 2024-03-11  16.250514  16.210540
# 2024-03-12  16.496425  16.505519
# 2024-03-13  16.815382  16.889564
# 2024-03-14  17.217361  17.143230
# 2024-03-15  17.498197  17.212011
# 2024-03-16  17.471902  17.109461
# 2024-03-17  17.262131  16.993243
# 2024-03-18  17.061653  16.962485
# 2024-03-19  16.958460  17.017276
# 2024-03-20  16.976903  16.999815
# 2024-03-21  16.973861  16.869575
# 2024-03-22  16.847904  16.717213
# 2024-03-23  16.821907  16.682224
# 2024-03-24  16.995996  16.862975
# 2024-03-25  17.286205  17.158158
# 2024-03-26  17.621394  17.387444
# 2024-03-27  17.826721  17.469205
# 2024-03-28  17.815390  17.414288
# 2024-03-29  17.664567  17.322904
# 2024-03-30  17.498146  17.277446
# 2024-03-31  17.398244  17.275074
# 2024-04-01  17.363662  17.245309
# 2024-04-02  17.328810  17.150920
# 2024-04-03  17.275287  17.056080
# 2024-04-04  17.291666  17.052294
# 2024-04-05  17.440927  17.190529
# 2024-04-06  17.691542  17.418174
# 2024-04-07  17.956785  17.612315
# 2024-04-08  18.121165  17.697380
# 2024-04-09  18.126324  17.673653
# 2024-04-10  18.015150  17.603849
# 2024-04-11  17.874362  17.549798
# 2024-04-12  17.769211  17.518308
# 2024-04-13  17.708415  17.476890
# 2024-04-14  17.668744  17.408453
# 2024-04-15  17.650486  17.351145
# 2024-04-16  17.693066  17.365705
# 2024-04-17  17.830666  17.480999
# 2024-04-18  18.041859  17.661037
#
# Results for dataframe_8:
# Errors: {'MSE': 0.04364045916399238, 'MAE': 0.15531449666344732, 'R2': 0.981726528133698, 'MSAE': 0.04364045916399236}
# Forecast:
#                     y1         y2
#                     y          y
# 2024-03-02  14.928031  16.833439
# 2024-03-03  14.755709  16.801787
# 2024-03-04  14.525565  16.669291
# 2024-03-05  14.244880  16.532909
# 2024-03-06  14.162619  16.579594
# 2024-03-07  14.320030  16.684802
# 2024-03-08  14.510073  16.637319
# 2024-03-09  14.459316  16.511395
# 2024-03-10  14.194204  16.259235
# 2024-03-11  13.990891  16.171363
# 2024-03-12  14.079322  16.497715
# 2024-03-13  14.358919  16.941997
# 2024-03-14  14.542493  17.255213
# 2024-03-15  14.482210  17.273844
# 2024-03-16  14.205981  17.100592
# 2024-03-17  13.925054  16.953652
# 2024-03-18  13.836096  16.956355
# 2024-03-19  13.919212  17.016396
# 2024-03-20  14.014646  16.976433
# 2024-03-21  13.964401  16.830240
# 2024-03-22  13.770727  16.654008
# 2024-03-23  13.618802  16.639385
# 2024-03-24  13.675965  16.891979
# 2024-03-25  13.901163  17.262395
# 2024-03-26  14.101247  17.555873
# 2024-03-27  14.103230  17.618871
# 2024-03-28  13.900215  17.492380
# 2024-03-29  13.663493  17.348800
# 2024-03-30  13.565188  17.308446
# 2024-03-31  13.617090  17.334128
# 2024-04-01  13.692114  17.309083
# 2024-04-02  13.661812  17.194566
# 2024-04-03  13.528705  17.068104
# 2024-04-04  13.427333  17.080074
# 2024-04-05  13.484726  17.302134
# 2024-04-06  13.684562  17.632270
# 2024-04-07  13.879260  17.900704
# 2024-04-08  13.918834  17.980978
# 2024-04-09  13.783715  17.894007
# 2024-04-10  13.598924  17.768674
# 2024-04-11  13.507117  17.709249
# 2024-04-12  13.538722  17.709723
# 2024-04-13  13.604291  17.691432
# 2024-04-14  13.598741  17.613478
# 2024-04-15  13.515035  17.532434
# 2024-04-16  13.452512  17.563016
# 2024-04-17  13.512713  17.762504
# 2024-04-18  13.690760  18.058147
#
# Results for dataframe_9:
# Errors: {'MSE': 0.022775691034403397, 'MAE': 0.11231591343819272, 'R2': 0.9923341700837333, 'MSAE': 0.022775691034403404}
# Forecast:
#                     y1         y2
#                     y          y
# 2024-04-01  11.728305  16.761860
# 2024-05-01  11.861276  16.692575
# 2024-06-01  11.880547  16.512658
# 2024-07-01  11.850862  16.361706
# 2024-08-01  11.814794  16.414396
# 2024-09-01  11.949252  16.543859
# 2024-10-01  11.960130  16.509368
# 2024-11-01  11.828258  16.371809
# 2024-12-01  11.740618  16.057392
# 2025-01-01  11.735653  15.951238
# 2025-02-01  11.949780  16.316957
# 2025-03-01  12.193072  16.783642
# 2025-04-01  12.290337  17.076120
# 2025-05-01  12.345778  17.039357
# 2025-06-01  12.338611  16.816111
# 2025-07-01  12.326053  16.680194
# 2025-08-01  12.320975  16.693089
# 2025-09-01  12.375510  16.759424
# 2025-10-01  12.385454  16.758896
# 2025-11-01  12.324712  16.619730
# 2025-12-01  12.242969  16.394118
# 2026-01-01  12.227318  16.356331
# 2026-02-01  12.375316  16.619082
# 2026-03-01  12.562989  17.022569
# 2026-04-01  12.691496  17.345035
# 2026-05-01  12.740438  17.375506
# 2026-06-01  12.719927  17.204241
# 2026-07-01  12.702944  17.057462
# 2026-08-01  12.708164  17.029960
# 2026-09-01  12.734994  17.079620
# 2026-10-01  12.741163  17.091297
# 2026-11-01  12.704404  16.985012
# 2026-12-01  12.644813  16.833343
# 2027-01-01  12.638248  16.821181
# 2027-02-01  12.744137  17.035235
# 2027-03-01  12.901209  17.395357
# 2027-04-01  13.035045  17.703329
# 2027-05-01  13.090590  17.780662
# 2027-06-01  13.077844  17.666780
# 2027-07-01  13.057627  17.521595
# 2027-08-01  13.058256  17.464196
# 2027-09-01  13.077270  17.494006
# 2027-10-01  13.084901  17.510075
# 2027-11-01  13.060910  17.441786
# 2027-12-01  13.023089  17.343261
# 2028-01-01  13.027334  17.345870
# 2028-02-01  13.112380  17.530749
# 2028-03-01  13.250207  17.848677

# %%
def plot_forecasts(dfs):
    """
    Plots the forecasted values for each dataframe.
    
    Parameters:
    dfs (dict): Dictionary containing forecast dataframes for each concatenated dataframe.
    """
    for key, forecast_df in dfs.items():
        plt.figure(figsize=(10, 6))
        plt.plot(forecast_df.index, forecast_df['y1'], label='Forecast y1')
        plt.plot(forecast_df.index, forecast_df['y2'], label='Forecast y2')
        plt.title(f'Forecast for {key}')
        plt.xlabel('Date')
        plt.ylabel('Values')
        plt.legend()
        plt.show()

plot_forecasts(dfs)

# %%
dataframes_electro = [stateid_CA, stateid_CO, stateid_FL, stateid_MA, stateid_MN, stateid_NY, stateid_OH, stateid_TX, stateid_WA]


forecast_stateid_CA = dfs["dataframe_1"]
forecast_stateid_CO = dfs["dataframe_2"]
forecast_stateid_FL = dfs["dataframe_3"]
forecast_stateid_MA = dfs["dataframe_4"]
forecast_stateid_MN = dfs["dataframe_5"]
forecast_stateid_NY = dfs["dataframe_6"]
forecast_stateid_OH = dfs["dataframe_7"]
forecast_stateid_TX = dfs["dataframe_8"]
forecast_stateid_WA = dfs["dataframe_9"]

mean_CA = forecast_stateid_CA.mean()
mean_CO = forecast_stateid_CO.mean()
mean_FL = forecast_stateid_FL.mean()
mean_MA = forecast_stateid_MA.mean()
mean_MN = forecast_stateid_MN.mean()
mean_NY = forecast_stateid_NY.mean()
mean_OH = forecast_stateid_OH.mean()
mean_TX = forecast_stateid_TX.mean()
mean_WA = forecast_stateid_WA.mean()

# %%
dataframes_petrol_Midgrade = [stateid_SCA_Midgrade_Gasoline, stateid_SCO_Midgrade_Gasoline, stateid_SFL_Midgrade_Gasoline, stateid_SMA_Midgrade_Gasoline, stateid_SMN_Midgrade_Gasoline, stateid_SNY_Midgrade_Gasoline, stateid_SOH_Midgrade_Gasoline, stateid_STX_Midgrade_Gasoline, stateid_SWA_Midgrade_Gasoline]
dataframes_petrol_Regular = [stateid_SCA_Regular_Gasoline, stateid_SCO_Regular_Gasoline, stateid_SFL_Regular_Gasoline, stateid_SMA_Regular_Gasoline, stateid_SMN_Regular_Gasoline, stateid_SNY_Regular_Gasoline, stateid_SOH_Regular_Gasoline, stateid_STX_Regular_Gasoline, stateid_SWA_Regular_Gasoline]
dataframes_petrol_Premium = [stateid_SMN_Premium_Gasoline, stateid_SCA_Premium_Gasoline, stateid_SCO_Premium_Gasoline, stateid_SFL_Premium_Gasoline, stateid_SMA_Premium_Gasoline, stateid_SNY_Premium_Gasoline, stateid_SOH_Premium_Gasoline, stateid_STX_Premium_Gasoline , stateid_SWA_Premium_Gasoline]

# %%
results, dfs = fit_var_model_per_dataframe(dataframes_petrol_Premium, stateid_US= stateid_NUS_Premium_Gasoline, forecast_steps=204)
for key, value in results.items():
    print(f"\nResults for {key}:")
    print("Errors:", value['errors'])
    print("Forecast:\n", value['forecast'])
# Out:
# Dataframe 1 has duplicate index values. Dropping duplicates.
# Dataframe 2 has duplicate index values. Dropping duplicates.
# Dataframe 3 has duplicate index values. Dropping duplicates.
# Dataframe 4 has duplicate index values. Dropping duplicates.
# Dataframe 5 has duplicate index values. Dropping duplicates.
# Dataframe 6 has duplicate index values. Dropping duplicates.
# Dataframe 7 has duplicate index values. Dropping duplicates.
# Dataframe 8 has duplicate index values. Dropping duplicates.
# Dataframe 9 has duplicate index values. Dropping duplicates.
# Number of observations in concatenated Dataframe 1: 1254
# Number of variables in concatenated Dataframe 1: 2
# Initial maxlags for Dataframe 1: 15
# Optimal number of lags for Dataframe 1: 5
# Number of observations in concatenated Dataframe 2: 1256
# Number of variables in concatenated Dataframe 2: 2
# Initial maxlags for Dataframe 2: 15
# Optimal number of lags for Dataframe 2: 6
# Number of observations in concatenated Dataframe 3: 1254
# Number of variables in concatenated Dataframe 3: 2
# Initial maxlags for Dataframe 3: 15
# c:\Users\torei\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\torei\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\torei\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# Optimal number of lags for Dataframe 3: 4
# Number of observations in concatenated Dataframe 4: 1099
# Number of variables in concatenated Dataframe 4: 2
# Initial maxlags for Dataframe 4: 15
# Optimal number of lags for Dataframe 4: 4
# Number of observations in concatenated Dataframe 5: 1098
# Number of variables in concatenated Dataframe 5: 2
# Initial maxlags for Dataframe 5: 15
# Optimal number of lags for Dataframe 5: 4
# Number of observations in concatenated Dataframe 6: 1254
# Number of variables in concatenated Dataframe 6: 2
# Initial maxlags for Dataframe 6: 15
# c:\Users\torei\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\torei\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\torei\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# Optimal number of lags for Dataframe 6: 11
# Number of observations in concatenated Dataframe 7: 1098
# Number of variables in concatenated Dataframe 7: 2
# Initial maxlags for Dataframe 7: 15
# Optimal number of lags for Dataframe 7: 4
# Number of observations in concatenated Dataframe 8: 1254
# Number of variables in concatenated Dataframe 8: 2
# Initial maxlags for Dataframe 8: 15
# Optimal number of lags for Dataframe 8: 7
# Number of observations in concatenated Dataframe 9: 1100
# Number of variables in concatenated Dataframe 9: 2
# Initial maxlags for Dataframe 9: 15
# c:\Users\torei\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\torei\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# Optimal number of lags for Dataframe 9: 4
#
# Results for dataframe_1:
# Errors: {'MSE': 0.00024734759997602793, 'MAE': 0.010726606005465524, 'R2': 0.9951024809218458, 'MSAE': 0.00024734759997602825}
# Forecast:
#                    y1        y2
#                    y         y
# 2024-06-18  1.017125  1.135066
# 2024-06-19  1.018662  1.130166
# 2024-06-20  1.019882  1.127381
# 2024-06-21  1.020096  1.124963
# 2024-06-22  1.021337  1.123474
# ...              ...       ...
# 2025-01-03  0.842817  0.896589
# 2025-01-04  0.842439  0.896181
# 2025-01-05  0.842066  0.895778
# 2025-01-06  0.841696  0.895379
# 2025-01-07  0.841330  0.894984
#
# [204 rows x 2 columns]
#
# Results for dataframe_2:
# Errors: {'MSE': 0.00019674668495560512, 'MAE': 0.008695670177811091, 'R2': 0.9970681561064212, 'MSAE': 0.00019674668495560507}
# Forecast:
#                    y1        y2
#                    y         y
# 2024-06-18  1.322410  1.139470
# 2024-06-19  1.316689  1.134879
# 2024-06-20  1.313338  1.132572
# 2024-06-21  1.310471  1.130775
# 2024-06-22  1.307586  1.127694
# ...              ...       ...
# 2025-01-03  1.015129  0.895791
# 2025-01-04  1.014686  0.895399
# 2025-01-05  1.014248  0.895011
# 2025-01-06  1.013814  0.894627
# 2025-01-07  1.013385  0.894247
#
# [204 rows x 2 columns]
#
# Results for dataframe_3:
# Errors: {'MSE': 0.00015916898224236172, 'MAE': 0.008203848803848602, 'R2': 0.9969020416773755, 'MSAE': 0.00015916898224236183}
# Forecast:
#                    y1        y2
#                    y         y
# 2024-06-18  1.055848  1.138567
# 2024-06-19  1.063848  1.136754
# 2024-06-20  1.069170  1.134692
# 2024-06-21  1.072531  1.132874
# 2024-06-22  1.074673  1.131134
# ...              ...       ...
# 2025-01-03  0.870924  0.902445
# 2025-01-04  0.870563  0.902045
# 2025-01-05  0.870204  0.901648
# 2025-01-06  0.869850  0.901255
# 2025-01-07  0.869498  0.900865
#
# [204 rows x 2 columns]
#
# Results for dataframe_4:
# Errors: {'MSE': 0.000201820566112984, 'MAE': 0.009484195234126244, 'R2': 0.9944492882414537, 'MSAE': 0.00020182056611298412}
# Forecast:
#                    y1        y2
#                    y         y
# 2024-06-18  1.041199  1.139784
# 2024-06-19  1.036669  1.133116
# 2024-06-20  1.032067  1.126734
# 2024-06-21  1.028819  1.121056
# 2024-06-22  1.025352  1.115268
# ...              ...       ...
# 2025-01-03  0.865832  0.890346
# 2025-01-04  0.865783  0.890287
# 2025-01-05  0.865735  0.890228
# 2025-01-06  0.865688  0.890171
# 2025-01-07  0.865642  0.890115
#
# [204 rows x 2 columns]
#
# Results for dataframe_5:
# Errors: {'MSE': 0.00015554681440745917, 'MAE': 0.007727975898053034, 'R2': 0.9961067474048406, 'MSAE': 0.00015554681440745923}
# Forecast:
#                    y1        y2
#                    y         y
# 2024-06-18  1.151053  1.139203
# 2024-06-19  1.145220  1.133920
# 2024-06-20  1.139108  1.129466
# 2024-06-21  1.133176  1.125453
# 2024-06-22  1.127255  1.121547
# ...              ...       ...
# 2025-01-03  0.886728  0.901013
# 2025-01-04  0.886590  0.900876
# 2025-01-05  0.886454  0.900742
# 2025-01-06  0.886321  0.900610
# 2025-01-07  0.886190  0.900480
#
# [204 rows x 2 columns]
#
# Results for dataframe_6:
# Errors: {'MSE': 0.00013610129005206872, 'MAE': 0.007141309242965472, 'R2': 0.9974995848859061, 'MSAE': 0.00013610129005206864}
# Forecast:
#                    y1        y2
#                    y         y
# 2024-06-18  1.135507  1.138409
# 2024-06-19  1.131367  1.137240
# 2024-06-20  1.128450  1.135978
# 2024-06-21  1.125389  1.133411
# 2024-06-22  1.123694  1.132084
# ...              ...       ...
# 2025-01-03  0.935889  0.914962
# 2025-01-04  0.935518  0.914567
# 2025-01-05  0.935150  0.914175
# 2025-01-06  0.934785  0.913787
# 2025-01-07  0.934423  0.913402
#
# [204 rows x 2 columns]
#
# Results for dataframe_7:
# Errors: {'MSE': 0.0005114731884793421, 'MAE': 0.015970734813662138, 'R2': 0.9868130873483485, 'MSAE': 0.0005114731884793419}
# Forecast:
#                    y1        y2
#                    y         y
# 2024-06-18  1.147383  1.139839
# 2024-06-19  1.129809  1.134470
# 2024-06-20  1.113503  1.127222
# 2024-06-21  1.100576  1.120460
# 2024-06-22  1.089550  1.113962
# ...              ...       ...
# 2025-01-03  0.871165  0.897764
# 2025-01-04  0.871058  0.897651
# 2025-01-05  0.870953  0.897540
# 2025-01-06  0.870850  0.897431
# 2025-01-07  0.870748  0.897324
#
# [204 rows x 2 columns]
#
# Results for dataframe_8:
# Errors: {'MSE': 0.0001789577089055192, 'MAE': 0.008887781979735294, 'R2': 0.9962987498324178, 'MSAE': 0.00017895770890551913}
# Forecast:
#                    y1        y2
#                    y         y
# 2024-06-18  0.995247  1.139082
# 2024-06-19  0.994054  1.134722
# 2024-06-20  0.993233  1.133761
# 2024-06-21  0.996882  1.135842
# 2024-06-22  0.995914  1.135645
# ...              ...       ...
# 2025-01-03  0.914650  1.026296
# 2025-01-04  0.914345  1.025896
# 2025-01-05  0.914041  1.025498
# 2025-01-06  0.913739  1.025101
# 2025-01-07  0.913437  1.024706
#
# [204 rows x 2 columns]
#
# Results for dataframe_9:
# Errors: {'MSE': 0.00014158985652584546, 'MAE': 0.007880411778357348, 'R2': 0.9966966071813044, 'MSAE': 0.00014158985652584533}
# Forecast:
#                    y1        y2
#                    y         y
# 2024-06-24  1.232429  1.139387
# 2024-07-01  1.222496  1.133367
# 2024-07-08  1.216524  1.130506
# 2024-07-15  1.212465  1.128272
# 2024-07-22  1.208712  1.125677
# ...              ...       ...
# 2028-04-17  0.965419  0.907679
# 2028-04-24  0.965235  0.907509
# 2028-05-01  0.965053  0.907341
# 2028-05-08  0.964875  0.907176
# 2028-05-15  0.964699  0.907014
#
# [204 rows x 2 columns]

# %%
#results = fit_var_model_per_dataframe(dataframes_petrol, stateid_US= )

# %%
mean_SMN_Premium = dfs["dataframe_1"].mean()
#mean_SCA_Premium = dfs["dataframe_             ds         y\n0    2024-06-17  1.024835\n1    2024-06-10  1.024042\n2    2024-06-03  1.035403\n3    2024-05-27  1.086129\n4    2024-05-20  1.035403\n...         ...       ...\n1249 2000-07-03  0.461030\n1250 2000-06-26  0.495905\n1251 2000-06-19  0.519947\n1252 2000-06-12  0.502774\n1253 2000-06-05  0.452576\n\n[1254 rows x 2 columns]"].mean()
#mean_SCO_Premium = dfs["dataframe_             ds         y\n0    2024-06-17  1.038838\n1    2024-06-10  1.048349\n2    2024-06-03  1.081374\n3    2024-05-27  1.101717\n4    2024-05-20  1.086129\n...         ...       ...\n1094 2003-06-23  0.439366\n1095 2003-06-16  0.441215\n1096 2003-06-09  0.433289\n1097 2003-06-02  0.432232\n1098 2003-05-26  0.432232\n\n[1099 rows x 2 columns]"].mean()
#mean_SFL_Premium = dfs["dataframe_             ds         y\n0    2024-06-17  1.050462\n1    2024-06-10  1.017437\n2    2024-06-03  1.053104\n3    2024-05-27  1.039630\n4    2024-05-20  1.065258\n...         ...       ...\n1249 2000-07-03  0.496962\n1250 2000-06-26  0.499868\n1251 2000-06-19  0.491413\n1252 2000-06-12  0.470806\n1253 2000-06-05  0.458388\n\n[1254 rows x 2 columns]"].mean()
#mean_SMA_Premium = dfs["dataframe_             ds         y\n0    2024-06-17  1.141876\n1    2024-06-10  1.147424\n2    2024-06-03  1.159313\n3    2024-05-27  1.164597\n4    2024-05-20  1.168296\n...         ...       ...\n1249 2000-07-03  0.495641\n1250 2000-06-26  0.489300\n1251 2000-06-19  0.485073\n1252 2000-06-12  0.472919\n1253 2000-06-05  0.463672\n\n[1254 rows x 2 columns]"].mean()
#mean_SNY_Premium = dfs["dataframe_             ds         y\n0    2024-06-17  1.154822\n1    2024-06-10  1.157199\n2    2024-06-03  1.165654\n3    2024-05-27  1.167768\n4    2024-05-20  1.169089\n...         ...       ...\n1093 2003-06-23  0.444650\n1094 2003-06-16  0.446499\n1095 2003-06-09  0.442008\n1096 2003-06-02  0.445707\n1097 2003-05-26  0.447820\n\n[1098 rows x 2 columns]"].mean()
#mean_SOH_Premium = dfs["dataframe_             ds         y\n0    2024-06-17  1.179128\n1    2024-06-10  1.116777\n2    2024-06-03  1.149273\n3    2024-05-27  1.177543\n4    2024-05-20  1.213474\n...         ...       ...\n1093 2003-06-23  0.419551\n1094 2003-06-16  0.452048\n1095 2003-06-09  0.443593\n1096 2003-06-02  0.412417\n1097 2003-05-26  0.426420\n\n[1098 rows x 2 columns]"].mean()
#mean_STX_Premium = dfs["dataframe_             ds         y\n0    2024-06-17  1.245178\n1    2024-06-10  1.266843\n2    2024-06-03  1.286658\n3    2024-05-27  1.317569\n4    2024-05-20  1.314135\n...         ...       ...\n1095 2003-06-23  0.475033\n1096 2003-06-16  0.473712\n1097 2003-06-09  0.463937\n1098 2003-06-02  0.462880\n1099 2003-05-26  0.463672\n\n[1100 rows x 2 columns]"].mean()
mean_SWA_Premium = dfs["dataframe_9"].mean()

# %%
mean_SWA_Premium
# Out:
# y1  y    1.035516
# y2  y    0.971785
# dtype: float64

# %%
mean_WA
# Out:
# y1  y    12.504916
# y2  y    16.958682
# dtype: float64

# %%
def plot_correlation_heatmaps(dataframes):
    for stateid, df in dataframes.items():
        # Calculate the correlation matrix
        corr_matrix = df.corr()
        
        # Plot the heatmap
        plt.figure(figsize=(10, 8))
        sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', cbar=True)
        plt.title(f'Correlation Matrix for stateid {stateid}')
        plt.show()

# %%
#plot_correlation_heatmaps(stateid_dfs)

# %%
def prophet_forecast(dataframes_petrol, forecast_period=600, test_size=0.2):
    """
    Perform Prophet forecasting, plot using Plotly, and evaluate using error metrics for a list of DataFrames.

    Parameters:
    - data_list (list of DataFrame): List of DataFrames, each containing columns 'ds' (datetime) and 'y' (numeric).
    - forecast_period (int): Number of periods to forecast into the future.
    - test_size (float): Proportion of data to use as test set.

    Returns:
    - forecasts (list of DataFrame): List of forecasted values with columns 'ds', 'yhat', 'yhat_lower', 'yhat_upper'.
    """
    forecasts = []
    
    for data in dataframes_petrol:
        # Train-test split
        train_size = int(0.8*len(data))
        X_train = data.iloc[:train_size]
        X_test = data.iloc[train_size:]
        
        # Initialize Prophet model
        m = Prophet()
        
        # Fit model on training data
        m.fit(X_train)
        
        # Create future dataframe for forecasting
        future = m.make_future_dataframe(periods=forecast_period)
        
        # Forecast
        forecast = m.predict(future)
        forecasts.append(forecast)
        
        # Plot forecast using Plotly
        fig = plot_plotly(m, forecast)
        fig.show()
        
        # Plot components using Plotly
        fig_components = plot_components_plotly(m, forecast)
        fig_components.show()
        
        # Evaluate forecast using error metrics
        y_true = X_test['y']
        y_pred = forecast.iloc[-len(X_test):]['yhat']
        
        # Calculate error metrics
        mae = mean_absolute_error(y_true, y_pred)
        mse = mean_squared_error(y_true, y_pred)
        rmse = mean_squared_error(y_true, y_pred, squared=False)
        r2 = r2_score(y_true, y_pred)
        
        print(f"Mean Absolute Error (MAE): {mae}")
        print(f"Mean Squared Error (MSE): {mse}")
        print(f"Root Mean Squared Error (RMSE): {rmse}")
        print(f"R-squared (R2) Score: {r2}")
    
    return forecasts


forecasts = prophet_forecast(dataframes_petrol)

# %%
def calculate_break_even(
    gas_car_selling_price, gas_km_per_year, gas_price_per_liter, gas_liters_per_100km,
    electric_car_price, electric_price_per_kwh, electric_kwh_per_100km
):
    # Calculate the cost per kilometer for both cars
    gas_cost_per_km = (gas_price_per_liter * gas_liters_per_100km) / 100
    electric_cost_per_km = (electric_price_per_kwh * electric_kwh_per_100km) / 100

    # Calculate the net initial investment required to switch to the electric car
    net_initial_investment = electric_car_price - gas_car_selling_price

    # Calculate the break-even point in kilometers driven
    if gas_cost_per_km <= electric_cost_per_km:
        # If the gas car is cheaper to operate per km than the electric car,
        # a breakeven point will never be reached.
        return float('inf'), float('inf')

    break_even_km = net_initial_investment / (gas_cost_per_km - electric_cost_per_km)

    # Calculate the break-even point in years
    break_even_years = break_even_km / gas_km_per_year

    return break_even_km, break_even_years

def main():
    print("Enter the following information:")

    gas_car_selling_price = float(input("Selling price of the gas car (in dollars): "))
    gas_km_per_year = float(input("Kilometers driven per year with the gas car: "))
    gas_price_per_liter = float(input("Price of gas per liter (in dollars): "))
    gas_liters_per_100km = float(input("Liters of gas per 100 kilometers: "))

    electric_car_price = float(input("Price of the electric car (in dollars): "))
    electric_price_per_kwh = float(input("Price of electricity per kWh (in dollars): "))
    electric_kwh_per_100km = float(input("kWh per 100 kilometers for the electric car: "))

    break_even_km, break_even_years = calculate_break_even(
        gas_car_selling_price, gas_km_per_year, gas_price_per_liter, gas_liters_per_100km,
        electric_car_price, electric_price_per_kwh, electric_kwh_per_100km
    )

    if break_even_km == float('inf'):
        print("The electric car is not cheaper to operate than the gas car. No breakeven point will be reached.")
    else:
        print(f"Break-even distance: {break_even_km:.2f} km")
        print(f"Break-even time: {break_even_years:.2f} years")

# %%
main()
# Out:
# Enter the following information:
# Break-even distance: 200803.21 km
# Break-even time: 13.39 years

# %%
'''pandas interpolate for nans

## dont use arima or sarima!!

prophet as first baseline model
-> xgBoost   class timeseries legs

plot with both prices -> correlations
try to understand the trends -> moving averadge / seasonality

# %%
#wieghted mean
#explain VAR modell
#explain preprocss
stateid_CA

# %%
stateid_SCA_Premium_Gasoline
# Out:
#               ds         y
# 9     2024-06-17  1.332893
# 34    2024-06-10  1.353765
# 57    2024-06-03  1.386790
# 90    2024-05-27  1.413474
# 125   2024-05-20  1.428798
# ...          ...       ...
# 33246 2000-06-19  0.481902
# 33248 2000-06-12  0.482166
# 33273 2000-06-05  0.481902
# 33282 2000-05-29  0.484280
# 33284 2000-05-22  0.485073
#
# [1259 rows x 2 columns]
